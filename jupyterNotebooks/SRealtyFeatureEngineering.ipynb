# %%
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
from collections import Counter
from sklearn.preprocessing import MinMaxScaler

pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
np.seterr(divide = 'ignore') 

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"/pythonScripts")

from URL_helper import URL_helper

df = pd.read_csv('/Users/eugenganenco/Desktop/srealtyAnalysis/data/DataFile 16_11_2022_22_43/housesDf_17_11_2022_00_06_15.csv translatedWithCoordAndPrice.csv')
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df = df.loc[:, ~df.columns.str.contains('ID')]

# %%
df['Gas'].unique()
# Out:
# array([nan, 'Individuální', 'Plynovod', 'Individuální, Plynovod'],
#       dtype=object)

# %%
df = df.loc[df['price'] != 0]
df.drop(['link', 'location', 'total price', 'Update', 'Move-in date', 'Discounted', 'Original price'], inplace=True, axis=1)
df.head()
# Out:
#   district       HouseType  \
# 0     cheb  rodinne-domy\n
# 1     cheb  rodinne-domy\n
# 2     cheb  rodinne-domy\n
# 3     cheb  rodinne-domy\n
# 4     cheb  rodinne-domy\n
#
#                                                              Note on price  \
# 0  V případě více zájemců může RK využít pro výběr kupujícího formu aukce.
# 1                             včetně provize, právních i finančních služeb
# 2                             včetně provize, právních i finančních služeb
# 3  V případě více zájemců může RK využít pro výběr kupujícího formu aukce.
# 4                                                                      NaN
#
#   Building      Object status Location of the house   Object location  \
# 0  Cihlová              Dobrý            Samostatný        Okraj obce
# 1  Cihlová              Dobrý                Řadový  Klidná část obce
# 2  Cihlová        Velmi dobrý            Samostatný  Klidná část obce
# 3  Cihlová  Před rekonstrukcí            Samostatný  Klidná část obce
# 4  Cihlová        Velmi dobrý                   NaN               NaN
#
#   House type The floor Usable area Land area  Parking  Year of reconstruction  \
# 0    Patrový         2      196 m2    681 m2      3.0                  2022.0
# 1    Patrový         3      150 m2    356 m2      NaN                     NaN
# 2    Patrový         2      230 m2    977 m2      NaN                     NaN
# 3    Patrový         3      300 m2  11600 m2      4.0                     NaN
# 4    Patrový         3      675 m2   1004 m2      NaN                     NaN
#
#              Water              Heating                    Garbage  \
# 0  Dálkový vodovod      Lokální plynové  Veřejná kanalizace, Jímka
# 1     Místní zdroj                  NaN        ČOV pro celý objekt
# 2  Dálkový vodovod     Ústřední plynové         Veřejná kanalizace
# 3     Místní zdroj  Lokální tuhá paliva                     Septik
# 4              NaN                  NaN                        NaN
#
#   Electricity                             Transport  \
# 0        230V                      Silnice, Autobus
# 1        230V                      Silnice, Autobus
# 2        230V  Vlak, Dálnice, Silnice, MHD, Autobus
# 3  230V, 400V                      Silnice, Autobus
# 4         NaN                                   NaN
#
#                              Energy efficiency of the building Equipment  \
# 0             Třída C - Úsporná č. 148/2007 Sb. podle vyhlášky         0
# 1                             Třída G - Mimořádně nehospodárná       NaN
# 2                             Třída G - Mimořádně nehospodárná         1
# 3  Třída F - Velmi nehospodárná č. 148/2007 Sb. podle vyhlášky  Částečně
# 4                                                          NaN       NaN
#
#    Lift                                      companyName  proximityIndex  \
# 0   0.0                                      M&M reality      846.615385
# 1   NaN  Česká Společnost Realitní / Jura ex alto s.r.o.     1422.466667
# 2   NaN  Česká Společnost Realitní / Jura ex alto s.r.o.     1923.666667
# 3   0.0                                      M&M reality     2438.769231
# 4   NaN                              Tout Puissant Almaz     1344.166667
#
#    Index Built-up area Store  Garage           Gas  Telecommunication  \
# 0      0           NaN   NaN     NaN           NaN                NaN
# 1      1         73 m2     1     1.0  Individuální  Telefon, Internet
# 2      2        130 m2   NaN     1.0      Plynovod  Telefon, Internet
# 3      3           NaN   NaN     NaN           NaN                NaN
# 4      5           NaN   NaN     NaN           NaN                NaN
#
#   Garden area  Year of approval  Swimming pool Cena Floor area Communication  \
# 0         NaN               NaN            NaN  NaN        NaN           NaN
# 1         NaN               NaN            NaN  NaN        NaN           NaN
# 2      806 m2            2011.0            NaN  NaN        NaN           NaN
# 3         NaN               NaN            NaN  NaN        NaN           NaN
# 4         NaN               NaN            1.0  NaN        NaN           NaN
#
#   Indicator of energy efficiency of the building  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Certificate of energy performance of the building  Barrier-free  \
# 0                                               NaN           NaN
# 1                                               NaN           NaN
# 2                                               NaN           NaN
# 3                                               NaN           NaN
# 4                                               NaN           NaN
#
#   Ceiling height Housing costs Number of flats Starting price Expert opinion  \
# 0            NaN           NaN             NaN            NaN            NaN
# 1            NaN           NaN             NaN            NaN            NaN
# 2            NaN           NaN             NaN            NaN            NaN
# 3            NaN           NaN             NaN            NaN            NaN
# 4            NaN           NaN             NaN            NaN            NaN
#
#   Minimum bid Auction principal Type of auction Place of auction  \
# 0         NaN               NaN             NaN              NaN
# 1         NaN               NaN             NaN              NaN
# 2         NaN               NaN             NaN              NaN
# 3         NaN               NaN             NaN              NaN
# 4         NaN               NaN             NaN              NaN
#
#   The date of the auction The date of the 1st inspection  \
# 0                     NaN                            NaN
# 1                     NaN                            NaN
# 2                     NaN                            NaN
# 3                     NaN                            NaN
# 4                     NaN                            NaN
#
#   The date of the 2nd inspection Auction decree Expert opinion.1 Pool area  \
# 0                            NaN            NaN              NaN       NaN
# 1                            NaN            NaN              NaN       NaN
# 2                            NaN            NaN              NaN       NaN
# 3                            NaN            NaN              NaN       NaN
# 4                            NaN            NaN              NaN       NaN
#
#   Condition Date of completion of construction  Soil construction  \
# 0       NaN                                NaN                NaN
# 1       NaN                                NaN                NaN
# 2       NaN                                NaN                NaN
# 3       NaN                                NaN                NaN
# 4       NaN                                NaN                NaN
#
#   Sale start date Inspection date Inspection date to Minimum purchase price  \
# 0             NaN             NaN                NaN                    NaN
# 1             NaN             NaN                NaN                    NaN
# 2             NaN             NaN                NaN                    NaN
# 3             NaN             NaN                NaN                    NaN
# 4             NaN             NaN                NaN                    NaN
#
#   Share size  Number of owners locationLat locationLong     price
# 0        NaN               NaN  50.1719781   12.3687621   6900000
# 1        NaN               NaN  50.2123211   12.2101758   2990000
# 2        NaN               NaN  50.0574633   12.3974368   9900000
# 3        NaN               NaN  50.2234326   12.3814405   4590000
# 4        NaN               NaN    49.95143   12.6850936  15000000

# %%
df['Parking'].apply(lambda x: 1 if pd.isna(x) else 0).sum()
# Out:
# 7751

# %%
def createFeatureDict(column):
    featureDict = Counter()
    featureList = df[column].tolist()
    for feature in featureList:
        if pd.isna(feature):
            continue
        featureDict.update([string.lower().lstrip() for string in re.split(',|;|/.', feature)])
    return featureDict

def followsPattern(text, pattern):
        return bool(re.search(pattern, text.lower().lstrip()))

def createFeature(column, featureDict):
    featureList = list(featureDict.keys())
    patternList = []
    for feature in featureList:
        if feature != '':
            print(feature)
            patternList.append(re.compile(f'.*{feature}'))
    for feature,patternToFollow in zip(featureList,patternList):
        df[feature] = df.loc[df[column].apply(followsPattern, pattern=patternToFollow),column].map(lambda x: 'True', na_action='ignore')

# %%
columnList = ['Heating', 'Garbage', 'Electricity', 'Telecommunication', 'Communication']

# %%
for column in columnList:
    df.loc[df[column].str.contains('<selenium.', na=False), column] = np.NaN

# %%
for column in columnList:
    df[column].fillna(f'{column}_Unknown', inplace=True)
    featureDict = createFeatureDict(column)
    createFeature(column, featureDict)
    df.drop(column, inplace=True, axis=1)
# Out:
# lokální plynové
# heating_unknown
# ústřední plynové
# lokální tuhá paliva
# jiné
# lokální elektrické
# ústřední tuhá paliva
# ústřední elektrické
# ústřední dálkové
# podlahové
# veřejná kanalizace
# jímka
# čov pro celý objekt
# septik
# garbage_unknown
# trativod
# 230v
# 400v
# electricity_unknown
# 120v
# telecommunication_unknown
# telefon
# internet
# kabelové rozvody
# satelit
# kabelová televize
# ostatní
# communication_unknown
# asfaltová
# neupravená
# dlážděná
# betonová
# zpevněná
# šotolina
# štěrková

# %% [markdown]
# ### I will first perform some modifications to the dataframe that should not cause to data leakage

# %%
def extractInt(string):
    return re.sub('(m2)', '', string)

featureList = [feature for feature in df.filter(like='area').columns]
featuresModified = df.loc[:,featureList].applymap(extractInt, na_action='ignore')

for feature in featureList:
    df[feature] = featuresModified[feature].values
    df[feature] = pd.to_numeric(df[feature], errors='coerce')

print(df.loc[:,featureList])

print(df['Built-up area'].dtypes)
# Out:
#        Usable area  Land area  Built-up area  Garden area  Floor area  \
# 0              196      681.0            NaN          NaN         NaN
# 1              150      356.0           73.0          NaN         NaN
# 2              230      977.0          130.0        806.0         NaN
# 3              300    11600.0            NaN          NaN         NaN
# 4              675     1004.0            NaN          NaN         NaN
# ...            ...        ...            ...          ...         ...
# 15544          166      691.0          222.0          NaN         NaN
# 15545           31      100.0           25.0          NaN         NaN
# 15546          101     1642.0            NaN          NaN         NaN
# 15550          112        1.0          145.0          NaN         NaN
# 15551          630     1050.0          218.0          NaN       831.0
#
#        Pool area
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 15544        NaN
# 15545        NaN
# 15546        NaN
# 15550        NaN
# 15551        NaN
#
# [13862 rows x 6 columns]
# float64

# %% [markdown]
# This exrtacts the numerical value of the "area" variables.

# %%
notesDict = Counter()
notesList = df['Note on price'].tolist()
for note in notesList:
    if pd.isna(note):
        continue
    notesDict.update([string.lower().lstrip() for string in re.split(',|;|/.', note)])
print(notesDict)
# Out:
# Counter({'včetně provize': 1489, 'včetně právního servisu': 1306, 'v případě více zájemců může rk využít pro výběr kupujícího formu aukce.': 1293, 'včetně poplatků': 664, 'včetně dph': 561, 'cena k jednání': 379, '+ provize rk': 252, 'včetně provize rk': 206, 'včetně provize a právního servisu': 154, 'včetně provize a právních služeb': 75, 'včetně provize rk a právního servisu': 69, 'cena včetně provize a právního servisu': 61, 'cena včetně provize rk': 57, 'cena včetně 1% provize': 48, 'včetně právního servisu a provize rk': 44, 'cena včetně provize': 41, 'na klíč': 40, 'vč. zákl. desky a dph': 39, '+ provize': 39, 'bez poplatků': 35, 'včetně provize rk a právních služeb': 31, 'vč. provize rk': 30, 'konečná cena': 29, 'neplatíte provizi': 29, 'advokátní úschovy': 28, 'vč. provize a právního servisu': 27, 'vč. provize a právních služeb': 27, 'k jednání': 26, 'vč. provize': 26, 'cena včetně provize a právních služeb': 26, 'právního servisu': 23, 'kupní cena včetně provize zprostředkovatele a právního servisu.': 23, 'lze financovat hypotečním úvěrem': 22, 'včetně právních služeb': 22, 'cena je včetně provize rk': 22, 'včetně poplatků a právního servisu': 22, 'cena za nemovitost je uvedena včetně provize rk. financování zajistíme.': 22, 'provize rk': 21, '- kč': 19, 'sleva': 19, 'pozemku': 19, 'cena je uvedena včetně provize a právního servisu.': 19, 'vč. dph': 19, '<selenium.webdriver.remote.webelement.webelement (session="7c904ca5a3622d98708b8a213b3d0a79"': 18, 'včetně právního servisu a provize': 18, 'cena je konečná': 17, 'cena včetně právního servisu a provize rk': 16, 'včetně služeb a provize rk': 16, 'včetně provize a právního servisu.': 16, 'cena včetně provize a právního servisu.': 16, 'neplatíte provizi.': 16, 'dph': 15, '': 14, 'cena včetně právního servisu a provize rk. v případě více zájemců může rk využít pro výběr kupujícího formu aukce.': 14, 'včetně provize realitní kanceláře': 14, 'cena je včetně provize rk. v případě více zájemců může rk využít pro výběr kupujícího formu aukce.': 14, 'právního a finančního servisu': 14, 'včetně provize rk.': 14, 'právního a hypotečního servisu': 14, 'cena včetně provize a právních služeb.': 14, 'cena včetně provize rk a právních služeb': 14, 'včetně provize rk a právního servisu. v případě více zájemců může rk využít pro výběr kupujícího formu aukce.': 13, 'cena včetně dph': 13, 'kompletní cena': 13, 'včetně veškerých poplatků a právních služeb': 13, 'sítí a dph': 13, 'včetně právního servisu. v případě více zájemců může rk využít pro výběr kupujícího formu aukce.': 12, 'cena je včetně provize a právního servisu': 12, 'vč. provize rk a právního servisu': 12, 'včetně realitního a právního servisu': 12, 'poplatků a právního servisu': 12, 'cena včetně domu': 12, 'bez dph': 11, 'za nemovitost': 11, 'vyvolávací': 11, '-kč': 11, '-': 10, '+ provize rk. v případě více zájemců může rk využít pro výběr kupujícího formu aukce.': 10, 'cena vč. provize rk': 10, 'bez právního servisu': 10, 'plus provize rk': 10, 'vč. právního servisu': 10, 'právního servisu a advokátní úschovy.': 10, 'dohoda možná': 10, 'cena včetně právních služeb a provize rk': 10, 'právního servisu a advokátní úschovy': 10, 'zlevněno': 10, 'cena je včetně provize': 10, 'garance ceny do 31.11.2022': 10, 'cena vč. právních služeb a provize rk': 9, 'cena včetně právního servisu': 9, 'nejnižší podání': 9, 'cena včetně odměny a právního servisu': 9, 'nehradí se daň z nabytí.': 9, 'cena vč. provize a právních služeb': 9, 'cena je včetně provize rk a právního servisu': 9, 'přímý prodej': 9, 'cena je včetně provize a veškerého právního servisu': 9, 'včetně právního servisu a provize rk. v případě více zájemců může rk využít pro výběr kupujícího formu aukce.': 8, 'včetně služeb rk': 8, 'vyvolávací cena.': 8, 'včetně právních služeb a provize rk': 8, 'cena včetně provize rk a kompletního právního servisu. v případě více zájemců může rk využít pro výběr kupujícího formu aukce.': 8, 'cena včetně provize rk a právního servisu': 8, '9 ...

# %% [markdown]
# The dictionary above sorts the types of notes found in 'Note on price' variable by frequency of occurance.

# %%
df['Note on price'].fillna('Nothing', inplace=True)
df.loc[df['Note on price'].str.contains('poplatků', re.IGNORECASE), ['Note on price']]
# Out:
#                                                                               Note on price
# 8                      včetně DPH, včetně poplatků, včetně provize, včetně právního servisu
# 10     včetně DPH, včetně poplatků, včetně provize, včetně právního servisu, cena k jednání
# 32                 včetně poplatků, včetně provize, včetně právního servisu, cena k jednání
# 154                                                               včetně veškerých poplatků
# 188                včetně poplatků, včetně provize, včetně právního servisu, cena k jednání
# ...                                                                                     ...
# 15395                              včetně poplatků, včetně provize, včetně právního servisu
# 15415                              včetně poplatků, včetně provize, včetně právního servisu
# 15418                              včetně poplatků, včetně provize, včetně právního servisu
# 15422                                                Uvedená cena bez provize RK a poplatků
# 15466                                               Včetně právních služeb a všech poplatků
#
# [907 rows x 1 columns]

# %% [markdown]
# Next I will try to extract from the 'Note on price' variable the information about whether the house price includes comission, legal fees, vat, fees and if the price is negotiable.

# %%
        
notelist = ['provize', 'právního', 'dph', 'poplatků']
patternList = []

for note in notelist:
    patternList.append(re.compile('.*(včetně|\+)\s?.*{}.*'.format(note)))
patternList.append(re.compile('.*cena k jednání'))
notelist.append('cena k jednání')

for note,patternToFollow in zip(notelist,patternList):
    df[note] = df.loc[df['Note on price'].apply(followsPattern, pattern=patternToFollow),'Note on price'].map(lambda x: 'True', na_action='ignore')

# %%
df.drop('Note on price', inplace=True, axis=1)

# %% [markdown]
# ### Data separation into training set and testing set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df,df['price'], test_size=0.1, random_state=0)

# %%
X_train.shape, X_test.shape
# Out:
# ((12475, 99), (1387, 99))

# %% [markdown]
# ## Missing values

# %% [markdown]
# ### Categorical Values

# %%
## First lets handle categorical features which are missing

def percentageMissing(feature):
    missingValues = X_train[feature].apply(lambda x: 1 if pd.isna(x) else 0).sum()
    return round((missingValues/len(X_train.axes[0])) * 100, 3)

def getMissingFeaturesDict(featuresWithNan):
    missingFeaturesDict = {}
    for feature in featuresWithNan:
        percentage = percentageMissing(feature)
        missingFeaturesDict[feature] = percentage
    return sorted(missingFeaturesDict.items(), key=lambda x: x[1], reverse=True)

featuresWithNan=[feature for feature in X_train.columns if X_train[feature].isnull().sum() > 0 and X_train[feature].dtypes=='O']
missingFeaturesDict = getMissingFeaturesDict(featuresWithNan)

for index, feature in enumerate(missingFeaturesDict):
    print('Variable "{}"" has {}% of its values missing'.format(missingFeaturesDict[index][0], missingFeaturesDict[index][1]))
# Out:
# Variable "Cena"" has 100.0% of its values missing
# Variable "Starting price"" has 100.0% of its values missing
# Variable "Expert opinion"" has 100.0% of its values missing
# Variable "Minimum bid"" has 100.0% of its values missing
# Variable "Auction principal"" has 100.0% of its values missing
# Variable "Type of auction"" has 100.0% of its values missing
# Variable "Place of auction"" has 100.0% of its values missing
# Variable "The date of the auction"" has 100.0% of its values missing
# Variable "The date of the 1st inspection"" has 100.0% of its values missing
# Variable "The date of the 2nd inspection"" has 100.0% of its values missing
# Variable "Auction decree"" has 100.0% of its values missing
# Variable "Expert opinion.1"" has 100.0% of its values missing
# Variable "Minimum purchase price"" has 100.0% of its values missing
# Variable "Share size"" has 99.968% of its values missing
# Variable "Inspection date to"" has 99.904% of its values missing
# Variable "šotolina"" has 99.816% of its values missing
# Variable "Inspection date"" has 99.295% of its values missing
# Variable "štěrková"" has 99.263% of its values missing
# Variable "Date of completion of construction"" has 99.006% of its values missing
# Variable "Number of flats"" has 98.934% of its values missing
# Variable "Ceiling height"" has 98.878% of its values missing
# Variable "trativod"" has 98.589% of its values missing
# Variable "Sale start date"" has 98.477% of its values missing
# Variable "Condition"" has 98.261% of its values missing
# Variable "betonová"" has 98.116% of its values missing
# Variable "ostatní"" has 98.076% of its values missing
# Variable "neupravená"" has 97.571% of its values missing
# Variable "zpevněná"" has 97.443% of its values missing
# Variable "ústřední dálkové"" has 97.267% of its values missing
# Variable "podlahové"" has 97.114% of its values missing
# Variable "cena k jednání"" has 96.986% of its values missing
# Variable "dlážděná"" has 96.842% of its values missing
# Variable "Housing costs"" has 96.689% of its values missing
# Variable "čov pro celý objekt"" has 96.489% of its values missing
# Variable "kabelové rozvody"" has 95.992% of its values missing
# Variable "kabelová televize"" has 95.784% of its values missing
# Variable "satelit"" has 95.679% of its values missing
# Variable "dph"" has 94.926% of its values missing
# Variable "Certificate of energy performance of the building"" has 94.701% of its values missing
# Variable "120v"" has 94.493% of its values missing
# Variable "poplatků"" has 93.916% of its values missing
# Variable "ústřední elektrické"" has 93.739% of its values missing
# Variable "jiné"" has 92.265% of its values missing
# Variable "telefon"" has 91.719% of its values missing
# Variable "Indicator of energy efficiency of the building"" has 91.527% of its values missing
# Variable "ústřední tuhá paliva"" has 90.06% of its values missing
# Variable "lokální elektrické"" has 89.956% of its values missing
# Variable "lokální plynové"" has 89.483% of its values missing
# Variable "septik"" has 86.453% of its values missing
# Variable "jímka"" has 86.148% of its values missing
# Variable "ústřední plynové"" has 85.739% of its values missing
# Variable "právního"" has 82.301% of its values missing
# Variable "internet"" has 78.541% of its values missing
# Variable "lokální tuhá paliva"" has 76.273% of its values missing
# Variable "garbage_unknown"" has 74.733% of its values missing
# Variable "provize"" has 73.579% of its values missing
# Variable "Gas"" has 70.525% of its values missing
# Variable "electricity_unknown"" has 68.561% of its values missing
# Variable "asfaltová"" has 65.571% of its values missing
# Variable "heating_unknown"" has 65.411% of its values missing
# Variable "Store"" has 64.649% of its values missing
# Variable "400v"" has 61.539% of its values missing
# Variable "veřejná kanalizace"" has 51.495% of its values missing
# Variable "Equipment"" has 40.786% of its values missing
# Variable "communication_unknown"" has 40.729% of its values missing
# Variable "Transport"" has 38.87% of its values missing
# Variable "230v"" has 38.549% of its values missing
# Variable "Water"" has 28.617% of its values missing
# Variable "Object location"" has 28.529% of its values missing
# Variable "telecommunication_unknown"" has 24.874% of its values missing
# Variable "The floor"" has 22.99% of its values missing
# Variable "Energy efficiency of the building"" has 12.721% of its values missing
# Variable "Location of the house"" has 10.236% of its values missing

# %%
print(X_train.shape)
cols = X_train.columns[X_train.isnull().mean()>0.98]
X_train.drop(cols, axis=1, inplace = True)
print(X_train.shape)
# Out:
# (12475, 99)
# (12475, 70)

# %% [markdown]
# This deletes the columns that have more than 98% missing values.

# %%
catFeaturesWithNan=[feature for feature in X_train.columns if X_train[feature].isnull().sum() > 0 and X_train[feature].dtypes=='O']
missingFeaturesDict = getMissingFeaturesDict(catFeaturesWithNan)

for index, feature in enumerate(missingFeaturesDict):
    print('Variable "{}"" has {}% of its values missing'.format(missingFeaturesDict[index][0], missingFeaturesDict[index][1]))
# Out:
# Variable "neupravená"" has 97.571% of its values missing
# Variable "zpevněná"" has 97.443% of its values missing
# Variable "ústřední dálkové"" has 97.267% of its values missing
# Variable "podlahové"" has 97.114% of its values missing
# Variable "cena k jednání"" has 96.986% of its values missing
# Variable "dlážděná"" has 96.842% of its values missing
# Variable "Housing costs"" has 96.689% of its values missing
# Variable "čov pro celý objekt"" has 96.489% of its values missing
# Variable "kabelové rozvody"" has 95.992% of its values missing
# Variable "kabelová televize"" has 95.784% of its values missing
# Variable "satelit"" has 95.679% of its values missing
# Variable "dph"" has 94.926% of its values missing
# Variable "Certificate of energy performance of the building"" has 94.701% of its values missing
# Variable "120v"" has 94.493% of its values missing
# Variable "poplatků"" has 93.916% of its values missing
# Variable "ústřední elektrické"" has 93.739% of its values missing
# Variable "jiné"" has 92.265% of its values missing
# Variable "telefon"" has 91.719% of its values missing
# Variable "Indicator of energy efficiency of the building"" has 91.527% of its values missing
# Variable "ústřední tuhá paliva"" has 90.06% of its values missing
# Variable "lokální elektrické"" has 89.956% of its values missing
# Variable "lokální plynové"" has 89.483% of its values missing
# Variable "septik"" has 86.453% of its values missing
# Variable "jímka"" has 86.148% of its values missing
# Variable "ústřední plynové"" has 85.739% of its values missing
# Variable "právního"" has 82.301% of its values missing
# Variable "internet"" has 78.541% of its values missing
# Variable "lokální tuhá paliva"" has 76.273% of its values missing
# Variable "garbage_unknown"" has 74.733% of its values missing
# Variable "provize"" has 73.579% of its values missing
# Variable "Gas"" has 70.525% of its values missing
# Variable "electricity_unknown"" has 68.561% of its values missing
# Variable "asfaltová"" has 65.571% of its values missing
# Variable "heating_unknown"" has 65.411% of its values missing
# Variable "Store"" has 64.649% of its values missing
# Variable "400v"" has 61.539% of its values missing
# Variable "veřejná kanalizace"" has 51.495% of its values missing
# Variable "Equipment"" has 40.786% of its values missing
# Variable "communication_unknown"" has 40.729% of its values missing
# Variable "Transport"" has 38.87% of its values missing
# Variable "230v"" has 38.549% of its values missing
# Variable "Water"" has 28.617% of its values missing
# Variable "Object location"" has 28.529% of its values missing
# Variable "telecommunication_unknown"" has 24.874% of its values missing
# Variable "The floor"" has 22.99% of its values missing
# Variable "Energy efficiency of the building"" has 12.721% of its values missing
# Variable "Location of the house"" has 10.236% of its values missing

# %% [markdown]
# The model starts here

# %%
def fillNaCatFeature(dataset,catFeaturesWithNan):
    data = X_train.copy()
    data[catFeaturesWithNan]=data[catFeaturesWithNan].fillna('Missing')
    return data

X_train = fillNaCatFeature(X_train,catFeaturesWithNan)

# %% [markdown]
# Iputes the cells with missingvalues with a values called 'Missing'

# %% [markdown]
# ### Numerical variables

# %%
numValsToCat = ['Barrier-free', 'Parking', 'Garage', 'Lift', 'Swimming pool']
for feature in numValsToCat:
    X_train[feature] = X_train[feature].fillna('Missing')

# %%
numFeatures = [feature for feature in X_train.columns if X_train[feature].dtypes != 'O' and feature not in ['Index']]
X_train[numFeatures]
# Out:
#        Usable area  Land area  Year of reconstruction  proximityIndex  \
# 151            734     5793.0                     NaN      249.083333
# 12063          643     2092.0                     NaN     1968.388889
# 9880           236      801.0                     NaN     1539.266667
# 557             90      521.0                     NaN     1889.875000
# 9011            40     1068.0                     NaN     2229.230769
# ...            ...        ...                     ...             ...
# 14717           50      320.0                     NaN     1772.125000
# 3571           180      717.0                     NaN      699.470588
# 10965          276     1618.0                     NaN     1827.266667
# 12062          650     2052.0                     NaN     1236.263158
# 2998            16      528.0                     NaN      620.187500
#
#        Built-up area  Garden area  Year of approval  Floor area     price
# 151            584.0       5209.0               NaN       734.0  11900000
# 12063          349.0       1743.0               NaN         NaN  30900000
# 9880           236.0          NaN               NaN         NaN   6499000
# 557             60.0          NaN               NaN         NaN   1299000
# 9011            47.0          NaN               NaN         NaN   2500000
# ...              ...          ...               ...         ...       ...
# 14717           25.0          NaN               NaN         NaN   1500000
# 3571            96.0          NaN               NaN         NaN   9950000
# 10965          172.0          NaN               NaN         NaN   3150000
# 12062          269.0          NaN               NaN         NaN  69000000
# 2998            16.0        512.0               NaN         NaN   1099000
#
# [12475 rows x 9 columns]

# %%
# Now lets handle numerical features which are missing
numFeaturesWithNan=[feature for feature in numFeatures if X_train[feature].isnull().sum()>1]    
missingFeaturesDict = getMissingFeaturesDict(numFeaturesWithNan)

for index, feature in enumerate(missingFeaturesDict):
    print('Variable "{}"" has {}% of its values missing'.format(missingFeaturesDict[index][0], missingFeaturesDict[index][1]))
# Out:
# Variable "Year of approval"" has 91.142% of its values missing
# Variable "Year of reconstruction"" has 89.892% of its values missing
# Variable "Garden area"" has 70.814% of its values missing
# Variable "Floor area"" has 70.405% of its values missing
# Variable "Built-up area"" has 34.453% of its values missing
# Variable "Land area"" has 0.072% of its values missing

# %% [markdown]
# ### Inpute data to numerical variables

# %%
X_train[numFeaturesWithNan]
# Out:
#        Land area  Year of reconstruction  Built-up area  Garden area  \
# 151       5793.0                     NaN          584.0       5209.0
# 12063     2092.0                     NaN          349.0       1743.0
# 9880       801.0                     NaN          236.0          NaN
# 557        521.0                     NaN           60.0          NaN
# 9011      1068.0                     NaN           47.0          NaN
# ...          ...                     ...            ...          ...
# 14717      320.0                     NaN           25.0          NaN
# 3571       717.0                     NaN           96.0          NaN
# 10965     1618.0                     NaN          172.0          NaN
# 12062     2052.0                     NaN          269.0          NaN
# 2998       528.0                     NaN           16.0        512.0
#
#        Year of approval  Floor area
# 151                 NaN       734.0
# 12063               NaN         NaN
# 9880                NaN         NaN
# 557                 NaN         NaN
# 9011                NaN         NaN
# ...                 ...         ...
# 14717               NaN         NaN
# 3571                NaN         NaN
# 10965               NaN         NaN
# 12062               NaN         NaN
# 2998                NaN         NaN
#
# [12475 rows x 6 columns]

# %%
for feature in numFeaturesWithNan:
    # There are many outliers in the dataset, therefore I will use the median.
    median=X_train[feature].median()
    
    # create a new feature to capture nan values
    X_train[feature + 'Nan'] = np.where(X_train[feature].isnull(), 1, 0)
    X_train[feature].fillna(median, inplace=True)

# %%
X_train[numFeaturesWithNan]
# Out:
#        Land area  Year of reconstruction  Built-up area  Garden area  \
# 151       5793.0                  2016.0          584.0       5209.0
# 12063     2092.0                  2016.0          349.0       1743.0
# 9880       801.0                  2016.0          236.0        504.0
# 557        521.0                  2016.0           60.0        504.0
# 9011      1068.0                  2016.0           47.0        504.0
# ...          ...                     ...            ...          ...
# 14717      320.0                  2016.0           25.0        504.0
# 3571       717.0                  2016.0           96.0        504.0
# 10965     1618.0                  2016.0          172.0        504.0
# 12062     2052.0                  2016.0          269.0        504.0
# 2998       528.0                  2016.0           16.0        512.0
#
#        Year of approval  Floor area
# 151              2013.0       734.0
# 12063            2013.0       148.0
# 9880             2013.0       148.0
# 557              2013.0       148.0
# 9011             2013.0       148.0
# ...                 ...         ...
# 14717            2013.0       148.0
# 3571             2013.0       148.0
# 10965            2013.0       148.0
# 12062            2013.0       148.0
# 2998             2013.0       148.0
#
# [12475 rows x 6 columns]

# %% [markdown]
# ### Normaliztion of numerical data

# %%
numFeatures=[feature for feature in X_train.columns if not bool(re.search(r'Nan$', feature)) 
             and X_train[feature].dtypes!='O' and feature not in ['Index']] 
for feature in numFeatures:
    X_train[feature]=np.log(X_train[feature])
X_train[numFeatures].head(5)
# Out:
#        Usable area  Land area  Year of reconstruction  proximityIndex  \
# 151       6.598509   8.664406                7.608871        5.517788
# 12063     6.466145   7.645876                7.608871        7.584971
# 9880      5.463832   6.685861                7.608871        7.339061
# 557       4.499810   6.255750                7.608871        7.544266
# 9011      3.688879   6.973543                7.608871        7.709412
#
#        Built-up area  Garden area  Year of approval  Floor area      price
# 151         6.369901     8.558143          7.607381    6.598509  16.292049
# 12063       5.855072     7.463363          7.607381    4.997212  17.246267
# 9880        5.463832     6.222576          7.607381    4.997212  15.687159
# 557         4.094345     6.222576          7.607381    4.997212  14.077105
# 9011        3.850148     6.222576          7.607381    4.997212  14.731801

# %% [markdown]
# ### Feature scaling

# %%
for feature in numFeatures:
    print('{}; min: {}; max: {}'.format(feature, X_train[feature].min(), X_train[feature].max()))
# Out:
# Usable area; min: 0.0; max: 10.699213884343516
# Land area; min: 0.0; max: 13.666759938199
# Year of reconstruction; min: 0.6931471805599453; max: 9.91447694733573
# proximityIndex; min: -inf; max: 8.42063334221138
# Built-up area; min: 0.0; max: 9.297160063928743
# Garden area; min: 0.0; max: 12.30965758578655
# Year of approval; min: 7.495541943884256; max: 7.6128310304073565
# Floor area; min: 0.0; max: 9.722924448757036
# price; min: 11.407564949312402; max: 19.209138104316636

# %%
X_train.loc[X_train['proximityIndex'] == X_train['proximityIndex'].min(), ['proximityIndex']] = X_train['proximityIndex'].median()

# %% [markdown]
# Substitute proximity index with '-inf' with median

# %%
scaler=MinMaxScaler()
X_train[numFeatures] = scaler.fit_transform(X_train[numFeatures])

X_train[numFeatures]
# Out:
#        Usable area  Land area  Year of reconstruction  proximityIndex  \
# 151       0.616728   0.633977                 0.74997        0.213542
# 12063     0.604357   0.559451                 0.74997        0.773597
# 9880      0.510676   0.489206                 0.74997        0.706973
# 557       0.420574   0.457735                 0.74997        0.762569
# 9011      0.344780   0.510256                 0.74997        0.807311
# ...            ...        ...                     ...             ...
# 14717     0.365636   0.422069                 0.74997        0.745140
# 3571      0.485359   0.481100                 0.74997        0.493283
# 10965     0.525310   0.540651                 0.74997        0.753441
# 12062     0.605369   0.558038                 0.74997        0.647583
# 2998      0.259139   0.458711                 0.74997        0.460690
#
#        Built-up area  Garden area  Year of approval  Floor area     price
# 151         0.685145     0.695238          0.953537    0.678655  0.626090
# 12063       0.629770     0.606301          0.953537    0.513962  0.748401
# 9880        0.587688     0.505504          0.953537    0.513962  0.548555
# 557         0.440387     0.505504          0.953537    0.513962  0.342180
# 9011        0.414121     0.505504          0.953537    0.513962  0.426098
# ...              ...          ...               ...         ...       ...
# 14717       0.346221     0.505504          0.953537    0.513962  0.360621
# 3571        0.490940     0.505504          0.953537    0.513962  0.603150
# 10965       0.553663     0.505504          0.953537    0.513962  0.455722
# 12062       0.601766     0.505504          0.953537    0.513962  0.851373
# 2998        0.298219     0.506783          0.953537    0.513962  0.320749
#
# [12475 rows x 9 columns]

# %%
X_train.to_csv('TrainingData.csv')
X_test.to_csv('TestingData.csv')

# %%
numFeatures = [feature for feature in X_train.columns if X_train[feature].dtypes != 'O' and feature not in ['Index']]
X_train[numFeatures]
# Out:
#        Usable area  Land area  Year of reconstruction  proximityIndex  \
# 151       0.616728   0.633977                 0.74997        0.213542
# 12063     0.604357   0.559451                 0.74997        0.773597
# 9880      0.510676   0.489206                 0.74997        0.706973
# 557       0.420574   0.457735                 0.74997        0.762569
# 9011      0.344780   0.510256                 0.74997        0.807311
# ...            ...        ...                     ...             ...
# 14717     0.365636   0.422069                 0.74997        0.745140
# 3571      0.485359   0.481100                 0.74997        0.493283
# 10965     0.525310   0.540651                 0.74997        0.753441
# 12062     0.605369   0.558038                 0.74997        0.647583
# 2998      0.259139   0.458711                 0.74997        0.460690
#
#        Built-up area  Garden area  Year of approval  Floor area     price  \
# 151         0.685145     0.695238          0.953537    0.678655  0.626090
# 12063       0.629770     0.606301          0.953537    0.513962  0.748401
# 9880        0.587688     0.505504          0.953537    0.513962  0.548555
# 557         0.440387     0.505504          0.953537    0.513962  0.342180
# 9011        0.414121     0.505504          0.953537    0.513962  0.426098
# ...              ...          ...               ...         ...       ...
# 14717       0.346221     0.505504          0.953537    0.513962  0.360621
# 3571        0.490940     0.505504          0.953537    0.513962  0.603150
# 10965       0.553663     0.505504          0.953537    0.513962  0.455722
# 12062       0.601766     0.505504          0.953537    0.513962  0.851373
# 2998        0.298219     0.506783          0.953537    0.513962  0.320749
#
#        Land areaNan  Year of reconstructionNan  Built-up areaNan  \
# 151               0                          1                 0
# 12063             0                          1                 0
# 9880              0                          1                 0
# 557               0                          1                 0
# 9011              0                          1                 0
# ...             ...                        ...               ...
# 14717             0                          1                 0
# 3571              0                          1                 0
# 10965             0                          1                 0
# 12062             0                          1                 0
# 2998              0                          1                 0
#
#        Garden areaNan  Year of approvalNan  Floor areaNan
# 151                 0                    1              0
# 12063               0                    1              1
# 9880                1                    1              1
# 557                 1                    1              1
# 9011                1                    1              1
# ...               ...                  ...            ...
# 14717               1                    1              1
# 3571                1                    1              1
# 10965               1                    1              1
# 12062               1                    1              1
# 2998                0                    1              1
#
# [12475 rows x 15 columns]

# %%
X_train
# Out:
#                district       HouseType  Building      Object status  \
# 151                cheb       chalupy\n   Cihlová        Velmi dobrý
# 12063              brno          vily\n   Cihlová        Velmi dobrý
# 9880    usti-nad-orlici       chalupy\n   Cihlová         Novostavba
# 557             sokolov  rodinne-domy\n   Cihlová  Před rekonstrukcí
# 9011   zdar-nad-sazavou         chaty\n   Dřevěná              Dobrý
# ...                 ...             ...       ...                ...
# 14717     frydek-mistek         chaty\n   Smíšená              Dobrý
# 3571             beroun          vily\n  Panelová        Velmi dobrý
# 10965        ceska-lipa  rodinne-domy\n   Smíšená  Před rekonstrukcí
# 12062              brno          vily\n   Cihlová     V rekonstrukci
# 2998           chomutov         chaty\n   Smíšená              Dobrý
#
#       Location of the house   Object location House type  \
# 151                 Missing           Missing    Patrový
# 12063            Samostatný        Okraj obce    Patrový
# 9880             Samostatný      Centrum obce    Patrový
# 557              Samostatný           Missing    Patrový
# 9011             Samostatný  Klidná část obce   Přízemní
# ...                     ...               ...        ...
# 14717            Samostatný  Klidná část obce    Patrový
# 3571             Samostatný      Centrum obce    Patrový
# 10965            Samostatný  Klidná část obce    Patrový
# 12062            Samostatný           Missing    Patrový
# 2998             Samostatný  Klidná část obce   Přízemní
#
#                    The floor  Usable area  Land area  Parking  \
# 151                        2     0.616728   0.633977      1.0
# 12063                      3     0.604357   0.559451      2.0
# 9880                       3     0.510676   0.489206  Missing
# 557                        1     0.420574   0.457735      1.0
# 9011   1. podlaží z celkem 1     0.344780   0.510256      1.0
# ...                      ...          ...        ...      ...
# 14717                      2     0.365636   0.422069  Missing
# 3571                       3     0.485359   0.481100  Missing
# 10965                      2     0.525310   0.540651      2.0
# 12062  3 včetně 1 podzemního     0.605369   0.558038      1.0
# 2998                 Missing     0.259139   0.458711  Missing
#
#        Year of reconstruction                          Water  \
# 151                   0.74997                         Studna
# 12063                 0.74997        Dálkový vodovod, Studna
# 9880                  0.74997                Dálkový vodovod
# 557                   0.74997                Dálkový vodovod
# 9011                  0.74997  Místní zdroj, Dálkový vodovod
# ...                       ...                            ...
# 14717                 0.74997                   Místní zdroj
# 3571                  0.74997                        Missing
# 10965                 0.74997                Dálkový vodovod
# 12062                 0.74997                        Missing
# 2998                  0.74997                        Missing
#
#                     Transport  \
# 151                   Missing
# 12063   Silnice, MHD, Autobus
# 9880   Vlak, Silnice, Autobus
# 557                   Autobus
# 9011         Silnice, Autobus
# ...                       ...
# 14717                 Missing
# 3571                  Missing
# 10965                 Autobus
# 12062                 Missing
# 2998    Silnice, MHD, Autobus
#
#                                      Energy efficiency of the building  \
# 151     Třída G - Mimořádně nehospodárná č. 78/2013 Sb. podle vyhlášky
# 12063             Třída D - Méně úsporná č. 78/2013 Sb. podle vyhlášky
# 9880   Třída G - Mimořádně nehospodárná č. 148/2007 Sb. podle vyhlášky
# 557                                   Třída G - Mimořádně nehospodárná
# 9011                                                           Missing
# ...                                                                ...
# 14717                                 Třída G - Mimořádně nehospodárná
# 3571             Třída E - Nehospodárná č. 264/2020 Sb. podle vyhlášky
# 10965                                 Třída G - Mimořádně nehospodárná
# 12062                                 Třída G - Mimořádně nehospodárná
# 2998                                                           Missing
#
#       Equipment     Lift              companyName  proximityIndex  Index  \
# 151           1  Missing         ERA Home Service        0.213542    154
# 12063  Částečně  Missing              REAL OFFICE        0.773597  12462
# 9880    Missing  Missing           RE/MAX Dynamic        0.706973  10203
# 557     Missing  Missing       Dumrealit.cz Bonus        0.762569    565
# 9011          1  Missing       Fincentrum Reality        0.807311   9311
# ...         ...      ...                      ...             ...    ...
# 14717   Missing  Missing  Optimal Finance, s.r.o.        0.745140  15210
# 3571          0  Missing        RE/MAX G8 Reality        0.493283   3672
# 10965   Missing  Missing     Reality 11 Liberecko        0.753441  11319
# 12062   Missing  Missing                  AMANDLA        0.647583  12461
# 2998   Částečně  Missing   Prosperity Real Estate        0.460690   3082
#
#        Built-up area    Store   Garage       Gas  Garden area  \
# 151         0.685145  Missing      1.0   Missing     0.695238
# 12063       0.629770        1      1.0  Plynovod     0.606301
# 9880        0.587688     9 m2      1.0   Missing     0.505504
# 557         0.440387        1  Missing   Missing     0.505504
# 9011        0.414121  Missing  Missing  Plynovod     0.505504
# ...              ...      ...      ...       ...          ...
# 14717       0.346221  Missing  Missing   Missing     0.505504
# 3571        0.490940  Missing  Missing   Missing     0.505504
# 10965       0.553663        1      1.0   Missing     0.505504
# 12062       0.601766        1      1.0   Missing     0.505504
# 2998        0.298219        1  Missing   Missing     0.506783
#
#        Year of approval Swimming pool  Floor area  \
# 151            0.953537       Missing    0.678655
# 12063          0.953537           1.0    0.513962
# 9880           0.953537       Missing    0.513962
# 557            0.953537       Missing    0.513962
# 9011           0.953537       Missing    0.513962
# ...                 ...           ...         ...
# 14717          0.953537       Missing    0.513962
# 3571           0.953537       Missing    0.513962
# 10965          0.953537       Missing    0.513962
# 12062          0.953537           1.0    0.513962
# 2998           0.953537       Missing    0.513962
#
#       Indicator of energy efficiency of the building  \
# 151                                          Missing
# 12063                           116,0 kWh/m^2 za rok
# 9880                                         Missing
# 557                                          Missing
# 9011                                         Missing
# ...                                              ...
# 14717                                        Missing
# 3571                                         Missing
# 10965                                        Missing
# 12062                                        Missing
# 2998                                         Missing
#
#       Certificate of energy performance of the building Barrier-free  \
# 151                                             Missing      Missing
# 12063                                           Missing      Missing
# 9880      Zobrazit průkaz energetické náročnosti budovy      Missing
# 557                                             Missing      Missing
# 9011                                            Missing      Missing
# ...                                                 ...          ...
# 14717                                           Missing          0.0
# 3571      Zobrazit průkaz energetické náročnosti budovy      Missing
# 10965                                           Missing      Missing
# 12062                                           Missing      Missing
# 2998                                            Missing      Missing
#
#       Housing costs locationLat        locationLong     price lokální plynové  \
# 151         Missing  49.9875604  12.874645217105748  0.626090         Missing
# 12063       Missing  49.2774571          16.6095407  0.748401         Missing
# 9880        Missing  50.0479103          16.5949808  0.548555         Missing
# 557         Missing  50.3487052          12.5103994  0.342180         Missing
# 9011        Missing  49.4705755          16.0874183  0.426098         Missing
# ...             ...         ...                 ...       ...             ...
# 14717       Missing    49.59994          18.3812642  0.360621         Missing
# 3571        Missing  49.8321686          13.8850731  0.603150         Missing
# 10965       Missing  50.7654108          14.4421418  0.455722         Missing
# 12062       Missing  49.2583565           16.593727  0.851373         Missing
# 2998        Missing  50.3761991          13.2710364  0.320749         Missing
#
#       heating_unknown ústřední plynové lokální tuhá paliva     jiné  \
# 151           Missing          Missing                True     True
# 12063         Missing             True                True  Missing
# 9880          Missing          Missing                True  Missing
# 557           Missing          Missing             Missing     True
# 9011          Missing          Missing                True  Missing
# ...               ...              ...                 ...      ...
# 14717         Missing          Missing                True  Missing
# 3571             True          Missing             Missing  Missing
# 10965         Missing          Missing             Missing  Missing
# 12062            True          Missing             Missing  Missing
# 2998             True          Missing             Missing  Missing
#
#       lokální elektrické ústřední tuhá paliva ústřední elektrické  \
# 151              Missing              Missing             Missing
# 12063            Missing              Missing             Missing
# 9880                True              Missing             Missing
# 557              Missing              Missing             Missing
# 9011                True              Missing             Missing
# ...                  ...                  ...                 ...
# 14717               True              Missing             Missing
# 3571             Missing              Missing             Missing
# 10965            Missing                 True             Missing
# 12062            Missing              Missing             Missing
# 2998             Missing              Missing             Missing
#
#       ústřední dálkové podlahové veřejná kanalizace    jímka  \
# 151            Missing   Missing            Missing  Missing
# 12063          Missing   Missing               True  Missing
# 9880           Missing   Missing            Missing  Missing
# 557            Missing   Missing            Missing  Missing
# 9011           Missing   Missing            Missing     True
# ...                ...       ...                ...      ...
# 14717          Missing   Missing            Missing  Missing
# 3571           Missing   Missing            Missing  Missing
# 10965          Missing   Missing            Missing  Missing
# 12062          Missing   Missing            Missing  Missing
# 2998           Missing   Missing            Missing  Missing
#
#       čov pro celý objekt   septik garbage_unknown     230v     400v  \
# 151               Missing  Missing            True  Missing     True
# 12063             Missing  Missing         Missing  Missing  Missing
# 9880              Missing     True         Missing     True     True
# 557               Missing     True         Missing     True  Missing
# 9011              Missing  Missing         Missing  Missing  Missing
# ...                   ...      ...             ...      ...      ...
# 14717             Missing  Missing            True  Missing  Missing
# 3571              Missing  Missing            True  Missing  Missing
# 10965             Missing     True         Missing     True  Missing
# 12062             Missing  Missing            True  Missing  Missing
# 2998              Missing  Missing            True  Missing  Missing
#
#       electricity_unknown     120v telecommunication_unknown  telefon  \
# 151               Missing  Missing                   Missing  Missing
# 12063                True  Missing                      True  Missing
# 9880              Missing  Missing                      True  Missing
# 557               Missing  Missing                      True  Missing
# 9011                 True  Missing                      True  Missing
# ...                   ...      ...                       ...      ...
# 14717                True  Missing                      True  Missing
# 3571                 True  Missing                      True  Missing
# 10965             Missing  Missing                      True  Missing
# 12062                True  Missing                      True  Missing
# 2998                 True  Missing                      True  Missing
#
#       internet kabelové rozvody  satelit kabelová televize  \
# 151       True          Missing  Missing           Missing
# 12063  Missing          Missing  Missing           Missing
# 9880   Missing          Missing  Missing           Missing
# 557    Missing          Missing  Missing           Missing
# 9011   Missing          Missing  Missing           Missing
# ...        ...              ...      ...               ...
# 14717  Missing          Missing  Missing           Missing
# 3571   Missing          Missing  Missing           Missing
# 10965  Missing          Missing  Missing           Missing
# 12062  Missing          Missing  Missing           Missing
# 2998   Missing          Missing  Missing           Missing
#
#       communication_unknown asfaltová neupravená dlážděná zpevněná  provize  \
# 151                    True   Missing    Missing  Missing  Missing  Missing
# 12063               Missing      True    Missing     True  Missing     True
# 9880                   True   Missing    Missing  Missing  Missing     True
# 557                    True   Missing    Missing  Missing  Missing     True
# 9011                Missing      True    Missing  Missing  Missing  Missing
# ...                     ...       ...        ...      ...      ...      ...
# 14717                  True   Missing    Missing  Missing  Missing  Missing
# 3571                   True   Missing    Missing  Missing  Missing  Missing
# 10965                  True   Missing    Missing  Missing  Missing     True
# 12062                  True   Missing    Missing  Missing  Missing     True
# 2998                Missing   Missing    Missing  Missing  Missing     True
#
#       právního      dph poplatků cena k jednání  Land areaNan  \
# 151    Missing  Missing  Missing        Missing             0
# 12063     True  Missing  Missing        Missing             0
# 9880      True  Missing  Missing        Missing             0
# 557       True  Missing  Missing        Missing             0
# 9011   Missing  Missing  Missing        Missing             0
# ...        ...      ...      ...            ...           ...
# 14717  Missing  Missing  Missing        Missing             0
# 3571   Missing  Missing  Missing        Missing             0
# 10965  Missing  Missing     True        Missing             0
# 12062  Missing  Missing  Missing        Missing             0
# 2998      True  Missing  Missing        Missing             0
#
#        Year of reconstructionNan  Built-up areaNan  Garden areaNan  \
# 151                            1                 0               0
# 12063                          1                 0               0
# 9880                           1                 0               1
# 557                            1                 0               1
# 9011                           1                 0               1
# ...                          ...               ...             ...
# 14717                          1                 0               1
# 3571                           1                 0               1
# 10965                          1                 0               1
# 12062                          1                 0               1
# 2998                           1                 0               0
#
#        Year of approvalNan  Floor areaNan
# 151                      1              0
# 12063                    1              1
# 9880                     1              1
# 557                      1              1
# 9011                     1              1
# ...                    ...            ...
# 14717                    1              1
# 3571                     1              1
# 10965                    1              1
# 12062                    1              1
# 2998                     1              1
#
# [12475 rows x 76 columns]

# %%
X_train['Swimming pool'].unique()
# Out:
# array(['Missing', 1.0], dtype=object)
