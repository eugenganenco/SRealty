# %%
import pandas as pd
import numpy as np

pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

DATA_PATH = '/Users/eugenganenco/Desktop/srealtyAnalysis/data/DataFile 16_11_2022_22_43/housesDf_17_11_2022_00_06_15.csv translatedWithCoordAndPrice.csv'
df = pd.read_csv(DATA_PATH)
df = df.loc[df['price'] != 0]
#df = df.loc[df['price'] < 10000000]
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
def adaptToSQL(dfColumns):
    return {x: x.lower().replace(" ", "_").replace("-", "_").replace(r"/", "_") \
                      .replace("\\", "_").replace(".", "_").replace("$", "").replace("%", "") for x in dfColumns}
df.rename(columns=adaptToSQL(df.columns), inplace = True)

# %%
print(df['House type'].unique())
print(df['HouseType'].unique())
print(df['district'].unique())
# Out:
# ['Patrový' 'Přízemní']
# ['rodinne-domy\n' 'vily\n' 'chalupy\n' 'chaty\n' 'projekty-na-klic\n'
#  'zemedelske-usedlosti\n' 'pamatky-jine\n' 'vicegeneracni-domy\n']
# ['cheb' 'karlovy-vary' 'sokolov' 'tachov' 'rokycany' 'plzen-sever' 'plzen'
#  'plzen-jih' 'klatovy' 'domazlice' 'usti-nad-labem' 'teplice' 'most'
#  'louny' 'litomerice' 'decin' 'chomutov' 'benesov' 'beroun' 'kladno'
#  'kolin' 'kutna-hora' 'melnik' 'mlada-boleslav' 'nymburk' 'praha-vychod'
#  'praha-zapad' 'pribram' 'rakovnik' 'praha-1' 'praha-2' 'praha-3'
#  'praha-4' 'praha-5' 'praha-6' 'praha-7' 'praha-8' 'praha-9' 'praha-10'
#  'ceske-budejovice' 'cesky-krumlov' 'jindrichuv-hradec' 'pisek'
#  'prachatice' 'strakonice' 'tabor' 'havlickuv-brod' 'jihlava' 'pelhrimov'
#  'trebic' 'zdar-nad-sazavou' 'chrudim' 'pardubice' 'svitavy'
#  'usti-nad-orlici' 'hradec-kralove' 'jicin' 'nachod' 'rychnov-nad-kneznou'
#  'trutnov' 'ceska-lipa' 'jablonec-nad-nisou' 'liberec' 'semily' 'blansko'
#  'breclav' 'brno' 'brno-venkov' 'hodonin' 'vyskov' 'znojmo' 'olomouc'
#  'prerov' 'jesenik' 'prostejov' 'sumperk' 'kromeriz' 'uherske-hradiste'
#  'vsetin' 'zlin' 'bruntal' 'frydek-mistek' 'karvina' 'novy-jicin' 'opava'
#  'ostrava']

# %%
df.head(1)
# Out:
#                                                                                  link  \
# 0  https://www.sreality.cz/detail/prodej/dum/rodinny/skalna-skalna-chebska/4024649548
#
#           location district       HouseType                 total price  \
# 0  Chebská, Skalná     cheb  rodinne-domy\n  6 900 000 Kč za nemovitost
#
#                                                              Note on price  \
# 0  V případě více zájemců může RK využít pro výběr kupujícího formu aukce.
#
#    Job ID Update Building Object status Location of the house Object location  \
# 0  817946  Včera  Cihlová         Dobrý            Samostatný      Okraj obce
#
#   House type The floor Usable area Land area  Parking Move-in date  \
# 0    Patrový         2      196 m2    681 m2      3.0        Ihned
#
#    Year of reconstruction            Water          Heating  \
# 0                  2022.0  Dálkový vodovod  Lokální plynové
#
#                      Garbage Electricity         Transport  \
# 0  Veřejná kanalizace, Jímka        230V  Silnice, Autobus
#
#                   Energy efficiency of the building Equipment  Lift  \
# 0  Třída C - Úsporná č. 148/2007 Sb. podle vyhlášky         0   0.0
#
#    companyName  proximityIndex  Index Built-up area Store  Garage  Gas  \
# 0  M&M reality      846.615385      0           NaN   NaN     NaN  NaN
#
#   Telecommunication Discounted Original price Garden area  Year of approval  \
# 0               NaN        NaN            NaN         NaN               NaN
#
#    Swimming pool Cena Floor area Communication  \
# 0            NaN  NaN        NaN           NaN
#
#   Indicator of energy efficiency of the building  \
# 0                                            NaN
#
#   Certificate of energy performance of the building  Barrier-free  \
# 0                                               NaN           NaN
#
#   Ceiling height  ID Housing costs Number of flats Starting price  \
# 0            NaN NaN           NaN             NaN            NaN
#
#   Expert opinion Minimum bid Auction principal Type of auction  \
# 0            NaN         NaN               NaN             NaN
#
#   Place of auction The date of the auction The date of the 1st inspection  \
# 0              NaN                     NaN                            NaN
#
#   The date of the 2nd inspection Auction decree Expert opinion.1 Pool area  \
# 0                            NaN            NaN              NaN       NaN
#
#   Condition Date of completion of construction  Soil construction  \
# 0       NaN                                NaN                NaN
#
#   Sale start date Inspection date Inspection date to Minimum purchase price  \
# 0             NaN             NaN                NaN                    NaN
#
#   Share size  Number of owners locationLat locationLong    price
# 0        NaN               NaN  50.1719781   12.3687621  6900000

# %%
## First lets handle categorical  which are missing
## Move to data analysis file

def percentageMissing(feature, data):
    missingValues = data[feature].apply(lambda x: 1 if pd.isna(x) else 0).sum()
    return round((missingValues/len(data.axes[0])) * 100, 3)

def getMissingDict(WithNan, data):
    missingDict = {}
    for feature in WithNan:
        percentage = percentageMissing(feature, data)
        missingDict[feature] = percentage
    return sorted(missingDict.items(), key=lambda x: x[1], reverse=True)

WithNan=[feature for feature in df.columns if df[feature].isnull().sum() > 0]
missingDict = getMissingDict(WithNan, df)

for index, feature in enumerate(missingDict):
    print('Variable "{}" has {}% of its values missing'.format(missingDict[index][0], missingDict[index][1]))
# Out:
# Variable "Cena" has 100.0% of its values missing
# Variable "Starting price" has 100.0% of its values missing
# Variable "Expert opinion" has 100.0% of its values missing
# Variable "The date of the 1st inspection" has 100.0% of its values missing
# Variable "The date of the 2nd inspection" has 100.0% of its values missing
# Variable "Minimum purchase price" has 100.0% of its values missing
# Variable "Minimum bid" has 99.993% of its values missing
# Variable "Auction principal" has 99.993% of its values missing
# Variable "Type of auction" has 99.993% of its values missing
# Variable "Place of auction" has 99.993% of its values missing
# Variable "The date of the auction" has 99.993% of its values missing
# Variable "Auction decree" has 99.993% of its values missing
# Variable "Expert opinion.1" has 99.993% of its values missing
# Variable "Number of owners" has 99.986% of its values missing
# Variable "Share size" has 99.971% of its values missing
# Variable "Inspection date to" has 99.899% of its values missing
# Variable "Inspection date" has 99.286% of its values missing
# Variable "Date of completion of construction" has 98.997% of its values missing
# Variable "Pool area" has 98.976% of its values missing
# Variable "Number of flats" has 98.947% of its values missing
# Variable "Ceiling height" has 98.875% of its values missing
# Variable "Soil construction" has 98.586% of its values missing
# Variable "Sale start date" has 98.478% of its values missing
# Variable "Condition" has 98.269% of its values missing
# Variable "Housing costs" has 96.689% of its values missing
# Variable "Discounted" has 95.931% of its values missing
# Variable "Original price" has 95.931% of its values missing
# Variable "Certificate of energy performance of the building" has 94.856% of its values missing
# Variable "Swimming pool" has 93.147% of its values missing
# Variable "ID" has 91.61% of its values missing
# Variable "Indicator of energy efficiency of the building" has 91.552% of its values missing
# Variable "Year of approval" has 91.185% of its values missing
# Variable "Year of reconstruction" has 89.9% of its values missing
# Variable "Barrier-free" has 79.685% of its values missing
# Variable "Telecommunication" has 75.141% of its values missing
# Variable "Move-in date" has 71.296% of its values missing
# Variable "Garden area" has 70.791% of its values missing
# Variable "Gas" has 70.43% of its values missing
# Variable "Floor area" has 70.358% of its values missing
# Variable "Lift" has 67.617% of its values missing
# Variable "Garage" has 65.842% of its values missing
# Variable "Store" has 64.724% of its values missing
# Variable "Communication" has 59.349% of its values missing
# Variable "Parking" has 55.915% of its values missing
# Variable "Note on price" has 46.422% of its values missing
# Variable "Equipment" has 40.564% of its values missing
# Variable "Transport" has 38.818% of its values missing
# Variable "Heating" has 34.526% of its values missing
# Variable "Built-up area" has 34.324% of its values missing
# Variable "Electricity" has 31.381% of its values missing
# Variable "Water" has 28.676% of its values missing
# Variable "Object location" has 28.474% of its values missing
# Variable "Garbage" has 25.35% of its values missing
# Variable "The floor" has 22.861% of its values missing
# Variable "Energy efficiency of the building" has 12.711% of its values missing
# Variable "Location of the house" has 10.186% of its values missing
# Variable "Job ID" has 8.39% of its values missing
# Variable "Land area" has 0.079% of its values missing

# %% [markdown]
# ## Split data

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(df, test_size=0.2, random_state=17)

# %%
X_train = train_set.drop('price', axis=1)
Y_train = train_set['price'].copy()

# %% [markdown]
# ## Adding data about regional characterisitcs

# %%
districts_data = pd.read_csv('/Users/eugenganenco/Desktop/srealtyAnalysis/data/Regional Data/Districts_of_the_Czech_Republic_1.csv')
regions_data = pd.read_csv('/Users/eugenganenco/Desktop/srealtyAnalysis/data/Regional Data/Regions_of_the_Czech_Republic_1.csv')

# %%
districts_data
# Out:
#                       Region             District Area\n(km2)  \
# 0                     Prague               Prague         496
# 1    Central Bohemian Region              Benešov       1,475
# 2    Central Bohemian Region               Beroun         662
# 3    Central Bohemian Region               Kladno         720
# 4    Central Bohemian Region                Kolín         748
# 5    Central Bohemian Region           Kutná Hora         917
# 6    Central Bohemian Region               Mělník         701
# 7    Central Bohemian Region       Mladá Boleslav       1,023
# 8    Central Bohemian Region              Nymburk         846
# 9    Central Bohemian Region          Prague-East         755
# 10   Central Bohemian Region          Prague-West         580
# 11   Central Bohemian Region              Příbram       1,693
# 12   Central Bohemian Region             Rakovník         896
# 13     South Bohemian Region     České Budějovice       1,639
# 14     South Bohemian Region        Český Krumlov       1,616
# 15     South Bohemian Region    Jindřichův Hradec       1,944
# 16     South Bohemian Region                Písek       1,127
# 17     South Bohemian Region           Prachatice       1,375
# 18     South Bohemian Region           Strakonice       1,032
# 19     South Bohemian Region                Tábor       1,326
# 20              Plzeň Region            Domažlice       1,052
# 21              Plzeň Region              Klatovy       1,946
# 22              Plzeň Region           Plzeň-City         261
# 23              Plzeň Region          Plzeň-South       1,068
# 24              Plzeň Region          Plzeň-North       1,287
# 25              Plzeň Region             Rokycany         575
# 26              Plzeň Region               Tachov       1,378
# 27       Karlovy Vary Region                 Cheb       1,046
# 28       Karlovy Vary Region         Karlovy Vary       1,515
# 29       Karlovy Vary Region              Sokolov         754
# 30     Ústí nad Labem Region             Chomutov         935
# 31     Ústí nad Labem Region                Děčín         909
# 32     Ústí nad Labem Region           Litoměřice       1,032
# 33     Ústí nad Labem Region                Louny       1,118
# 34     Ústí nad Labem Region                 Most         467
# 35     Ústí nad Labem Region              Teplice         469
# 36     Ústí nad Labem Region       Ústí nad Labem         405
# 37            Liberec Region           Česká Lípa       1,073
# 38            Liberec Region   Jablonec nad Nisou         439
# 39            Liberec Region              Liberec         989
# 40            Liberec Region               Semily         662
# 41     Hradec Králové Region       Hradec Králové         892
# 42     Hradec Králové Region                Jičín         887
# 43     Hradec Králové Region               Náchod         852
# 44     Hradec Králové Region  Rychnov nad Kněžnou         982
# 45     Hradec Králové Region              Trutnov       1,147
# 46          Pardubice Region              Chrudim         993
# 47          Pardubice Region            Pardubice         880
# 48          Pardubice Region              Svitavy       1,379
# 49          Pardubice Region      Ústí nad Orlicí       1,267
# 50           Vysočina Region       Havlíčkův Brod       1,265
# 51           Vysočina Region              Jihlava       1,199
# 52           Vysočina Region            Pelhřimov       1,290
# 53           Vysočina Region               Třebíč       1,463
# 54           Vysočina Region     Žďár nad Sázavou       1,579
# 55     South Moravian Region              Blansko         862
# 56     South Moravian Region              Břeclav       1,038
# 57     South Moravian Region            Brno-City         230
# 58     South Moravian Region         Brno-Country       1,499
# 59     South Moravian Region              Hodonín       1,099
# 60     South Moravian Region               Vyškov         876
# 61     South Moravian Region               Znojmo       1,590
# 62            Olomouc Region              Jeseník         719
# 63            Olomouc Region              Olomouc       1,620
# 64            Olomouc Region               Přerov         845
# 65            Olomouc Region            Prostějov         770
# 66            Olomouc Region              Šumperk       1,313
# 67               Zlín Region             Kroměříž         796
# 68               Zlín Region     Uherské Hradiště         991
# 69               Zlín Region               Vsetín       1,131
# 70               Zlín Region                 Zlín       1,046
# 71  Moravian-Silesian Region              Bruntál       1,537
# 72  Moravian-Silesian Region        Frýdek-Místek       1,208
# 73  Moravian-Silesian Region              Karviná         356
# 74  Moravian-Silesian Region           Nový Jičín         882
# 75  Moravian-Silesian Region                Opava       1,113
# 76  Moravian-Silesian Region         Ostrava-City         332
#
#    Population\n(2022)  Mun.
# 0           1,275,406     1
# 1              99,323   114
# 2              96,624    85
# 3             164,493   100
# 4             103,894    90
# 5              75,683    88
# 6             109,354    69
# 7             127,592   120
# 8             101,120    86
# 9             188,384   110
# 10            151,093    79
# 11            114,366   120
# 12             54,898    83
# 13            195,533   109
# 14             60,096    46
# 15             89,283   106
# 16             70,769    75
# 17             50,230    65
# 18             69,773   112
# 19            101,363   110
# 20             54,391    76
# 21             84,614    94
# 22            188,407    15
# 23             68,918    99
# 24             80,666    98
# 25             48,770    68
# 26             52,941    51
# 27             87,958    40
# 28            110,052    55
# 29             85,200    38
# 30            121,480    44
# 31            126,294    52
# 32            117,582   105
# 33             85,381    70
# 34            106,773    26
# 35            124,472    34
# 36            116,916    23
# 37            101,962    57
# 38             90,171    35
# 39            173,890    59
# 40             71,547    65
# 41            162,400   104
# 42             78,713   111
# 43            107,973    78
# 44             78,424    80
# 45            115,073    75
# 46            103,746   108
# 47            172,224   112
# 48            102,866   116
# 49            135,682   115
# 50             93,692   120
# 51            112,415   123
# 52             71,571   120
# 53            109,183   167
# 54            117,164   174
# 55            107,912   116
# 56            114,801    63
# 57            379,466     1
# 58            225,514   187
# 59            151,096    82
# 60             92,317    79
# 61            113,462   144
# 62             36,752    24
# 63            233,588    97
# 64            126,613   105
# 65            107,580    97
# 66            118,397    78
# 67            103,445    79
# 68            139,829    78
# 69            140,171    59
# 70            188,987    91
# 71             89,547    67
# 72            212,347    72
# 73            240,319    17
# 74            149,919    54
# 75            173,753    77
# 76            312,104    13

# %%
regions_data
# Out:
#    Licence\nplate             Region           Capital Population\n(2022)  \
# 0               A             Prague            Prague          1,275,406
# 1               S   Central Bohemian            Prague          1,386,824
# 2               C     South Bohemian  České Budějovice            637,047
# 3               P              Plzeň             Plzeň            578,707
# 4               K       Karlovy Vary      Karlovy Vary            283,210
# 5               U     Ústí nad Labem    Ústí nad Labem            798,898
# 6               L            Liberec           Liberec            437,570
# 7               H     Hradec Králové    Hradec Králové            542,583
# 8               E          Pardubice         Pardubice            514,518
# 9               J           Vysočina           Jihlava            504,025
# 10              B     South Moravian              Brno          1,184,568
# 11              M            Olomouc           Olomouc            622,930
# 12              Z               Zlín              Zlín            572,432
# 13              T  Moravian-Silesian           Ostrava          1,177,989
# 14             CZ     Czech Republic            Prague         10,516,707
#
#    Area\n(km2) Pop. density\n(/km2) GDP\n(million CZK, 2022) GDP per\ncapita
# 0          496                2,571                1,572,000       1,190,611
# 1       10,929                  127                  662,000         484,475
# 2       10,058                   63                  289,000         438,114
# 3        7,649                   76                  285,000         474,310
# 4        3,310                   86                   97,000         341,512
# 5        5,339                  150                  313,000         386,363
# 6        3,163                  138                  189,000         411,399
# 7        4,759                  114                  275,000         479,318
# 8        4,519                  114                  213,000         422,684
# 9        6,796                   74                  228,000         434,018
# 10       7,188                  165                  598,000         505,896
# 11       5,272                  118                  268,000         418,525
# 12       3,963                  144                  276,000         457,361
# 13       5,427                  217                  510,000         430,005
# 14      78,871                  136                5,775,000         538,816

# %% [markdown]
# The above data was obtained from Wikipedia

# %%
from sklearn.base import BaseEstimator, TransformerMixin
import re

class PrahaTransform(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        pattern = re.compile('praha-\d{1,2}$')
        X['district'] = X['district'].map(lambda x: 'Praha' if pattern.match(x) else x)    
        return X

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"/pythonScripts")
from URL_helper import URL_helper

# do something about the path. It's obnoxious.

class AddDistrictsAttributes(BaseEstimator, TransformerMixin):
        
    def fit(self, X, y=None):
        return self
    
    def __extractRegionsData(self, X, regions_data, y=None):
        regions_data = regions_data.drop(['Population\n(2022)', 'Area\n(km2)', 'Pop. density\n(/km2)', 'Licence\nplate'], axis=1)
        regions_data = regions_data.drop(14, axis=0)
        X['Region'] = X['Region'].map(lambda x: x.replace(' Region', ''), na_action='ignore')
        X['District'] = X['District'].map(lambda x: x.replace('-City', ''), na_action='ignore')
        X = pd.merge(regions_data, X)
        X['Is capital'] = np.where(X['Capital'] == X['District'], 1, 0)
        return X
    
    def __extractDistrictsData(self, X, districts_data, y=None):
        helper = URL_helper()
        X['Distric_in_czech'] = X['district'].map(helper.getEnglishNameToCzechDict())
        print(len(districts_data['District'].unique()))
        print(districts_data['District'].unique())
        print('////////')
        print(len(X['Distric_in_czech'].unique()))
        print(X['Distric_in_czech'].unique())
        print(f'In x and not in districts {list(set(X["Distric_in_czech"].unique()) - set(districts_data["District"].unique()))}')
        print(f'In districts and not in X {list(set(districts_data["District"].unique()) - set(X["Distric_in_czech"].unique()))}')
        X = pd.merge(X, districts_data, left_on='Distric_in_czech', right_on='District')
        return X
        
    def transform(self, X, y=None):
        regions_data = pd.read_csv('/Users/eugenganenco/Desktop/srealtyAnalysis/data/Regional Data/Regions_of_the_Czech_Republic_1.csv')
        districts_data = pd.read_csv('/Users/eugenganenco/Desktop/srealtyAnalysis/data/Regional Data/Districts_of_the_Czech_Republic_1.csv')
        
        X = self.__extractDistrictsData(X, districts_data)
        print(f'Shape: {X.shape}')
        X = self.__extractRegionsData(X, regions_data)   
        print(f'Shape: {X.shape}')
        X = X.drop(['district', 'Distric_in_czech', 'Region', 'Capital', 'District', 'Mun.'], axis=1)
        for feature in ['GDP\n(million CZK, 2022)', 'GDP per\ncapita', 'Area\n(km2)', 'Population\n(2022)']:
            if X[feature].dtypes == 'O':               
                X.loc[:,feature] = X.loc[:,feature].map(lambda x: x.replace(',',''), na_action='ignore')
                X.loc[:,feature] = pd.to_numeric(X.loc[:,feature])
        return X

# %%
# after AddDistrictsAttributes
class CombinedAttributesAdder(BaseEstimator, TransformerMixin):
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        X['Population density'] = X['Area\n(km2)'] / X['Population\n(2022)']
        print('Columns:')
        print(X.columns)
        self.columnNames = X.columns
        return X
    
    def get_feature_names(self):
        return self.columnNames

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Numercial values functions

# %%
class ImputeCoordinates(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        X[['locationLat', 'locationLong']] = X[['locationLat', 'locationLong']].apply(pd.to_numeric, errors='coerce')
        X['locationLat'] = X.groupby('district')['locationLat'].transform(lambda x: x.fillna(x.mean()))
        X['locationLong'] = X.groupby('district')['locationLong'].transform(lambda x: x.fillna(x.mean()))
        print(X.shape)
        return X

# %%
class ExtractAreaValue(BaseEstimator, TransformerMixin):

    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        featureList = [feature for feature in X.filter(like='area').columns]
        Modified = X.loc[:,featureList].applymap(lambda x: re.sub('(m2)', '', x), na_action='ignore')
        for feature in featureList:
            X[feature] = Modified[feature]
            X[feature] = pd.to_numeric(X[feature])
        return X

# %%
#class ExtractYearValue()

# %%
# class ExtractRighNumVars(BaseEstimator, TransformerMixin):
#     def fit(self, X, y=None):
#         return self
    
#     def transform(self, X, y=None):
#         X = X.loc[:,['district', 'Usable area', 'Land area', 'proximityIndex', 'Built-up area', 'Garden area', 'Floor area']]
#         return X

# %%
class DeleteIrrelevantColumns(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        X = X.loc[:, ~df.columns.str.contains('^Unnamed')]
        X = X.drop(['link', 'location', 'total price', 'Update', 'Move-in date', 'Discounted', 'Original price'], inplace=True, axis=1)
        return X

# %%
class CustonImputer(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        for feature in [feature for feature in X.columns if X[feature].dtypes != 'O']:
            median=X[feature].median()
            X[feature].fillna(median, inplace=True)
        return X

# %%
class Debug(BaseEstimator, TransformerMixin):

    def transform(self, X):
        print('////////////////////////////////////')
        print('////////////////////////////////////')
        print(pd.DataFrame(X).head(5))
        print(X.shape)
        print('////////////////////////////////////')
        print('////////////////////////////////////')
        return X

    def fit(self, X, y=None, **fit_params):
        return self

# %% [markdown]
# ### Categorical values functions

# %%
# class ExtractRightCatVars(BaseEstimator, TransformerMixin):
#     def transform(self, X, y=None):
#         return self
        
#     def fit(self, X, y=None):
#         columnListCategorical = set(X.columns) - set(['Usable area','Land area', 'proximityIndex', 'Built-up area', 'Floor area'])
#         return X[list(columnListCategorical)]

# %%
class GroupImputer(BaseEstimator, TransformerMixin):

    def __init__(self, group_cols, Y_train):
        self.group_cols = group_cols
        self.Y_train = Y_train
    
    def fit(self, X, y=None):
        impute_map = X.groupby(self.group_cols)[self.Y_train].agg(pd.Series.mode) \
                                                            .reset_index(drop=False)
        print(impute_map)
        self.impute_map_ = impute_map        
        return self 
    
    def transform(self, X, y=None):
        X = X.copy()       
        for index, row in self.impute_map_.iterrows():
            ind = (X[self.group_cols] == row[self.group_cols]).all(axis=1)
            X.loc[ind, self.Y_train] = X.loc[ind, self.Y_train].fillna(row[self.Y_train])      
        return X.values

# %% [markdown]
# ### Pipeline construction

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
#Do something about outliers
from sklearn.preprocessing import FunctionTransformer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

numPipeline = Pipeline([
        ('praha_transform', PrahaTransform()),
#         ('feature_selector', ExtractRighNumVars()),
#        ('ImputeCoordinates', ImputeCoordinates()),
        ('extract_area_vals', ExtractAreaValue()),
        ('add_districs_attributes', AddDistrictsAttributes()),
        ('add_combined_attributes', CombinedAttributesAdder()),
        ('imputer', IterativeImputer(verbose=2, max_iter=30, tol=1e-10)),
        ('LogTransformation', FunctionTransformer(lambda value: np.log1p(value))),
        ('std_scaler', MinMaxScaler())
    ])

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

catPipeline = Pipeline([
        ('oneHot', OneHotEncoder()),
        ('simpleImputer', SimpleImputer(strategy='most_frequent'))
])

# %%
from sklearn.compose import ColumnTransformer

THRESHOLD = 30
numericalValues = ['district', 'Usable area', 'Land area', 'proximityIndex', 'Built-up area', 'Garden area', 'Floor area']
irrelevantVariables = ['location', 'Auction decree', 'Move-in date', 'Cena', 'Index', 'Starting price', 'Place of auction', 'link',
                       'Original price', 'Update', 'Sale start date', 'locationLong', 'Expert opinion', 'Discounted', 
                       'The date of the auction', 'Expert opinion.1', 'Minimum purchase price', 'Type of auction', 'total price', 'ID', 'Job ID', 'locationLat']
# eliminate from categorical values variables that are not numeric and the ones that are either irrelevant (link, id) or that are proxy for the actial price ('Original price').
categoricalValues = list(set(X_train.columns) - set(numericalValues) - set(irrelevantVariables))
missingDict = getMissingDict(numericalValues + categoricalValues, X_train)
print(missingDict)
numericalValues = [feature for feature in numericalValues if dict(missingDict)[feature] < THRESHOLD]
categoricalValues = [feature for feature in categoricalValues if dict(missingDict)[feature] < THRESHOLD]
missingDict
print('')
print(f'Categorical  {categoricalValues}')
print('')
print(f'Numerical  {numericalValues}')

columnsPipeline = ColumnTransformer(
         transformers=[
        ('numPipeline', numPipeline, numericalValues),
        ('catPipeline', catPipeline, categoricalValues)
    ]
)
# Out:
# [('The date of the 1st inspection', 100.0), ('The date of the 2nd inspection', 100.0), ('Minimum bid', 99.991), ('Auction principal', 99.991), ('Number of owners', 99.991), ('Share size', 99.973), ('Inspection date to', 99.919), ('Inspection date', 99.369), ('Date of completion of construction', 99.053), ('Pool area', 98.954), ('Number of flats', 98.9), ('Ceiling height', 98.873), ('Soil construction', 98.539), ('Condition', 98.242), ('Housing costs', 96.627), ('Certificate of energy performance of the building', 94.878), ('Swimming pool', 93.065), ('Indicator of energy efficiency of the building', 91.821), ('Year of approval', 91.325), ('Year of reconstruction', 89.999), ('Barrier-free', 79.836), ('Telecommunication', 75.237), ('Floor area', 70.863), ('Garden area', 70.665), ('Gas', 70.43), ('Lift', 67.977), ('Garage', 65.885), ('Store', 64.532), ('Communication', 59.771), ('Parking', 56.083), ('Note on price', 46.082), ('Equipment', 40.644), ('Transport', 39.192), ('Heating', 34.71), ('Built-up area', 34.358), ('Electricity', 31.59), ('Water', 29.164), ('Object location', 28.83), ('Garbage', 25.674), ('The floor', 22.788), ('Energy efficiency of the building', 12.607), ('Location of the house', 10.208), ('Land area', 0.081), ('district', 0.0), ('Usable area', 0.0), ('proximityIndex', 0.0), ('Building', 0.0), ('House type', 0.0), ('HouseType', 0.0), ('Object status', 0.0), ('companyName', 0.0)]
#
# Categorical  ['Building', 'House type', 'HouseType', 'Object status', 'companyName', 'Location of the house', 'Energy efficiency of the building', 'Garbage', 'The floor', 'Object location', 'Water']
#
# Numerical  ['district', 'Usable area', 'Land area', 'proximityIndex']

# %%
X_train_prepared = columnsPipeline.fit_transform(X_train)
# Out:
# 77
# ['Prague' 'Benešov' 'Beroun' 'Kladno' 'Kolín' 'Kutná Hora' 'Mělník'
#  'Mladá Boleslav' 'Nymburk' 'Prague-East' 'Prague-West' 'Příbram'
#  'Rakovník' 'České Budějovice' 'Český Krumlov' 'Jindřichův Hradec' 'Písek'
#  'Prachatice' 'Strakonice' 'Tábor' 'Domažlice' 'Klatovy' 'Plzeň-City'
#  'Plzeň-South' 'Plzeň-North' 'Rokycany' 'Tachov' 'Cheb' 'Karlovy Vary'
#  'Sokolov' 'Chomutov' 'Děčín' 'Litoměřice' 'Louny' 'Most' 'Teplice'
#  'Ústí nad Labem' 'Česká Lípa' 'Jablonec nad Nisou' 'Liberec' 'Semily'
#  'Hradec Králové' 'Jičín' 'Náchod' 'Rychnov nad Kněžnou' 'Trutnov'
#  'Chrudim' 'Pardubice' 'Svitavy' 'Ústí nad Orlicí' 'Havlíčkův Brod'
#  'Jihlava' 'Pelhřimov' 'Třebíč' 'Žďár nad Sázavou' 'Blansko' 'Břeclav'
#  'Brno-City' 'Brno-Country' 'Hodonín' 'Vyškov' 'Znojmo' 'Jeseník'
#  'Olomouc' 'Přerov' 'Prostějov' 'Šumperk' 'Kroměříž' 'Uherské Hradiště'
#  'Vsetín' 'Zlín' 'Bruntál' 'Frýdek-Místek' 'Karviná' 'Nový Jičín' 'Opava'
#  'Ostrava-City']
# ////////
# 77
# ['Náchod' 'Semily' 'Sokolov' 'Prague-West' 'Tábor' 'Litoměřice'
#  'Brno-Country' 'Uherské Hradiště' 'Šumperk' 'Jičín' 'Nymburk' 'Děčín'
#  'Bruntál' 'Brno-City' 'Písek' 'Domažlice' 'Frýdek-Místek' 'Český Krumlov'
#  'Rakovník' 'Plzeň-City' 'Kladno' 'Strakonice' 'Benešov' 'Břeclav'
#  'Pelhřimov' 'Prachatice' 'Vyškov' 'Olomouc' 'Plzeň-South' 'Most'
#  'Trutnov' 'Karlovy Vary' 'Nový Jičín' 'Příbram' 'Jindřichův Hradec'
#  'Prague' 'Liberec' 'Teplice' 'Prostějov' 'Mladá Boleslav'
#  'Jablonec nad Nisou' 'Plzeň-North' 'Kutná Hora' 'Kroměříž' 'Karviná'
#  'Cheb' 'Zlín' 'Ostrava-City' 'Rychnov nad Kněžnou' 'Chrudim'
#  'Ústí nad Labem' 'Blansko' 'Louny' 'Beroun' 'Kolín' 'České Budějovice'
#  'Havlíčkův Brod' 'Klatovy' 'Jihlava' 'Žďár nad Sázavou' 'Pardubice'
#  'Mělník' 'Jeseník' 'Třebíč' 'Opava' 'Ústí nad Orlicí' 'Svitavy'
#  'Chomutov' 'Rokycany' 'Hradec Králové' 'Hodonín' 'Tachov' 'Česká Lípa'
#  'Prague-East' 'Přerov' 'Vsetín' 'Znojmo']
# In x and not in districts []
# In districts and not in X []
# Shape: (11089, 10)
# Shape: (11089, 14)
# Columns:
# Index(['GDP\n(million CZK, 2022)', 'GDP per\ncapita', 'Usable area',
#        'Land area', 'proximityIndex', 'Area\n(km2)', 'Population\n(2022)',
#        'Is capital', 'Population density'],
#       dtype='object')
# [IterativeImputer] Completing matrix with shape (11089, 9)
# [IterativeImputer] Ending imputation round 1/30, elapsed time 0.05
# [IterativeImputer] Change: 782.5962846996927, scaled tolerance: 0.0001572
# [IterativeImputer] Ending imputation round 2/30, elapsed time 0.08
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.0001572
# [IterativeImputer] Early stopping criterion reached.

# %%
# df = pd.DataFrame(_prepared, columns=['GDP\n(million CZK, 2022)', 'GDP per\ncapita', 'Usable area',
#        'Land area', 'proximityIndex', 'Built-up area', 'Floor area',
#        'Area\n(km2)', 'Population\n(2022)', 'Is capital',
#        'Population density'])

# %%
# df.head(2000)

# %%
X_train_prepared
# Out:
# <11089x2300 sparse matrix of type '<class 'numpy.float64'>'
# 	with 211206 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Select and train the model

# %% [markdown]
# ### Training the models

# %%
def display_scores(scores, algorithmName):
    print(algorithmName)
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())
    print()

# %%
from sklearn.model_selection import cross_val_score
import numpy as np

# could use dict with algorithm:ParamList as elements of algorithmList or args* for hyperparam tuning.
def runAlgorithmList(algorithmList, X_train, Y_train, scoringFormula="neg_mean_squared_error"):
    algorithmDict = {}
    for algorithm in algorithmList:
        scores = cross_val_score(algorithm, X_train, Y_train,
                         scoring=scoringFormula, cv=10)
        algorithm_scores = np.sqrt(-scores)
        display_scores(algorithm_scores, type(algorithm).__name__)
        algorithmDict[algorithm] = scores.mean()
    return min(algorithmDict, key=algorithmDict.get)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
import dill


bestModel = runAlgorithmList([LinearRegression()], #, SVR(kernel="linear"
                X_train_prepared, Y_train)

finalPipeline = Pipeline([('preprocessor', columnsPipeline),
                         ('model', bestModel)])

finalPipeline.fit(X_train, Y_train)
print(type(finalPipeline))

with open('../telegramBot/model.pickle', 'wb') as f:
    dill.dump(finalPipeline, f)
# Out:
# LinearRegression
# Scores: [5323547.15213337 8144336.39106354 6366756.61222618 5109323.03181355
#  6483842.92826018 5179849.76234778 5855826.04053304 5927412.76524535
#  5445801.08689666 4869483.94127969]
# Mean: 5870617.971179933
# Standard deviation: 912918.0804965609
#
# 77
# ['Prague' 'Benešov' 'Beroun' 'Kladno' 'Kolín' 'Kutná Hora' 'Mělník'
#  'Mladá Boleslav' 'Nymburk' 'Prague-East' 'Prague-West' 'Příbram'
#  'Rakovník' 'České Budějovice' 'Český Krumlov' 'Jindřichův Hradec' 'Písek'
#  'Prachatice' 'Strakonice' 'Tábor' 'Domažlice' 'Klatovy' 'Plzeň-City'
#  'Plzeň-South' 'Plzeň-North' 'Rokycany' 'Tachov' 'Cheb' 'Karlovy Vary'
#  'Sokolov' 'Chomutov' 'Děčín' 'Litoměřice' 'Louny' 'Most' 'Teplice'
#  'Ústí nad Labem' 'Česká Lípa' 'Jablonec nad Nisou' 'Liberec' 'Semily'
#  'Hradec Králové' 'Jičín' 'Náchod' 'Rychnov nad Kněžnou' 'Trutnov'
#  'Chrudim' 'Pardubice' 'Svitavy' 'Ústí nad Orlicí' 'Havlíčkův Brod'
#  'Jihlava' 'Pelhřimov' 'Třebíč' 'Žďár nad Sázavou' 'Blansko' 'Břeclav'
#  'Brno-City' 'Brno-Country' 'Hodonín' 'Vyškov' 'Znojmo' 'Jeseník'
#  'Olomouc' 'Přerov' 'Prostějov' 'Šumperk' 'Kroměříž' 'Uherské Hradiště'
#  'Vsetín' 'Zlín' 'Bruntál' 'Frýdek-Místek' 'Karviná' 'Nový Jičín' 'Opava'
#  'Ostrava-City']
# ////////
# 77
# ['Náchod' 'Semily' 'Sokolov' 'Prague-West' 'Tábor' 'Litoměřice'
#  'Brno-Country' 'Uherské Hradiště' 'Šumperk' 'Jičín' 'Nymburk' 'Děčín'
#  'Bruntál' 'Brno-City' 'Písek' 'Domažlice' 'Frýdek-Místek' 'Český Krumlov'
#  'Rakovník' 'Plzeň-City' 'Kladno' 'Strakonice' 'Benešov' 'Břeclav'
#  'Pelhřimov' 'Prachatice' 'Vyškov' 'Olomouc' 'Plzeň-South' 'Most'
#  'Trutnov' 'Karlovy Vary' 'Nový Jičín' 'Příbram' 'Jindřichův Hradec'
#  'Prague' 'Liberec' 'Teplice' 'Prostějov' 'Mladá Boleslav'
#  'Jablonec nad Nisou' 'Plzeň-North' 'Kutná Hora' 'Kroměříž' 'Karviná'
#  'Cheb' 'Zlín' 'Ostrava-City' 'Rychnov nad Kněžnou' 'Chrudim'
#  'Ústí nad Labem' 'Blansko' 'Louny' 'Beroun' 'Kolín' 'České Budějovice'
#  'Havlíčkův Brod' 'Klatovy' 'Jihlava' 'Žďár nad Sázavou' 'Pardubice'
#  'Mělník' 'Jeseník' 'Třebíč' 'Opava' 'Ústí nad Orlicí' 'Svitavy'
#  'Chomutov' 'Rokycany' 'Hradec Králové' 'Hodonín' 'Tachov' 'Česká Lípa'
#  'Prague-East' 'Přerov' 'Vsetín' 'Znojmo']
# In x and not in districts []
# In districts and not in X []
# Shape: (11089, 10)
# Shape: (11089, 14)
# Columns:
# Index(['GDP\n(million CZK, 2022)', 'GDP per\ncapita', 'Usable area',
#        'Land area', 'proximityIndex', 'Area\n(km2)', 'Population\n(2022)',
#        'Is capital', 'Population density'],
#       dtype='object')
# [IterativeImputer] Completing matrix with shape (11089, 9)
# [IterativeImputer] Ending imputation round 1/30, elapsed time 0.03
# [IterativeImputer] Change: 782.5962846996927, scaled tolerance: 0.0001572
# [IterativeImputer] Ending imputation round 2/30, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.0001572
# [IterativeImputer] Early stopping criterion reached.
# <class 'sklearn.pipeline.Pipeline'>

# %% [markdown]
# ### Evaluating the models

# %% [markdown]
# ## Evaluate Your System on the Test Set

# %%
from sklearn.metrics import mean_squared_error
final_model = lin_reg

X_test = test_set.drop('price', axis=1)
y_test = test_set['price'].copy()

X_test_prepared = num_pipeline.transform(X_test)
final_predictions = final_model.predict(X_test_prepared)

final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 from sklearn.metrics import mean_squared_error
# ----> 2 final_model = lin_reg
#       4 X_test = test_set.drop('price', axis=1)
#       5 y_test = test_set['price'].copy()
#
# NameError: name 'lin_reg' is not defined

# %%
X_test_prepared

# %%
final_model.coef_

# %% [markdown]
# 'Usable area', 'Land area', 'proximityIndex', 'Built-up area', 'Garden area', 'Floor area'

# %%
final_model.intercept_

# %%
final_rmse

# %%
print(final_predictions[:10])
y_test[:10]
