# %%
import pandas as pd

pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

DATA_PATH = '/Users/eugenganenco/Desktop/srealtyAnalysis/data/DataFile 16_11_2022_22_43/housesDf_17_11_2022_00_06_15.csv translatedWithCoordAndPrice.csv'
df = pd.read_csv(DATA_PATH)
df = df.loc[df['price'] != 0]

# %%
df.head(1)
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 0             0             0           0
#
#                                                                                  link  \
# 0  https://www.sreality.cz/detail/prodej/dum/rodinny/skalna-skalna-chebska/4024649548
#
#           location district       HouseType                 total price  \
# 0  Chebská, Skalná     cheb  rodinne-domy\n  6 900 000 Kč za nemovitost
#
#                                                              Note on price  \
# 0  V případě více zájemců může RK využít pro výběr kupujícího formu aukce.
#
#    Job ID Update Building Object status Location of the house Object location  \
# 0  817946  Včera  Cihlová         Dobrý            Samostatný      Okraj obce
#
#   House type The floor Usable area Land area  Parking Move-in date  \
# 0    Patrový         2      196 m2    681 m2      3.0        Ihned
#
#    Year of reconstruction            Water          Heating  \
# ...

# %%
## First lets handle categorical features which are missing
## Move to data analysis file

def percentageMissing(feature):
    missingValues = df[feature].apply(lambda x: 1 if pd.isna(x) else 0).sum()
    return round((missingValues/len(df.axes[0])) * 100, 3)

def getMissingFeaturesDict(featuresWithNan):
    missingFeaturesDict = {}
    for feature in featuresWithNan:
        percentage = percentageMissing(feature)
        missingFeaturesDict[feature] = percentage
    return sorted(missingFeaturesDict.items(), key=lambda x: x[1], reverse=True)

featuresWithNan=[feature for feature in df.columns if df[feature].isnull().sum() > 0]
missingFeaturesDict = getMissingFeaturesDict(featuresWithNan)

for index, feature in enumerate(missingFeaturesDict):
    print('Variable "{}"" has {}% of its values missing'.format(missingFeaturesDict[index][0], missingFeaturesDict[index][1]))
# Out:
# Variable "Cena"" has 100.0% of its values missing
# Variable "Starting price"" has 100.0% of its values missing
# Variable "Expert opinion"" has 100.0% of its values missing
# Variable "The date of the 1st inspection"" has 100.0% of its values missing
# Variable "The date of the 2nd inspection"" has 100.0% of its values missing
# Variable "Minimum purchase price"" has 100.0% of its values missing
# Variable "Minimum bid"" has 99.993% of its values missing
# Variable "Auction principal"" has 99.993% of its values missing
# Variable "Type of auction"" has 99.993% of its values missing
# Variable "Place of auction"" has 99.993% of its values missing
# Variable "The date of the auction"" has 99.993% of its values missing
# Variable "Auction decree"" has 99.993% of its values missing
# Variable "Expert opinion.1"" has 99.993% of its values missing
# Variable "Number of owners"" has 99.986% of its values missing
# Variable "Share size"" has 99.971% of its values missing
# ...

# %% [markdown]
# ## Split data

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(df, test_size=0.2, random_state=17)

# %%
features = train_set.drop("price", axis=1)
target = train_set['price'].copy()

# %% [markdown]
# ## Adding data about regional characterisitcs

# %%
districts_data = pd.read_csv('/Users/eugenganenco/Desktop/srealtyAnalysis/data/Regional Data/Districts_of_the_Czech_Republic_1.csv')
regions_data = pd.read_csv('/Users/eugenganenco/Desktop/srealtyAnalysis/data/Regional Data/Regions_of_the_Czech_Republic_1.csv')

# %%
districts_data
# Out:
#                       Region             District Area\n(km2)  \
# 0                     Prague               Prague         496
# 1    Central Bohemian Region              Benešov       1,475
# 2    Central Bohemian Region               Beroun         662
# 3    Central Bohemian Region               Kladno         720
# 4    Central Bohemian Region                Kolín         748
# 5    Central Bohemian Region           Kutná Hora         917
# 6    Central Bohemian Region               Mělník         701
# 7    Central Bohemian Region       Mladá Boleslav       1,023
# 8    Central Bohemian Region              Nymburk         846
# 9    Central Bohemian Region          Prague-East         755
# 10   Central Bohemian Region          Prague-West         580
# 11   Central Bohemian Region              Příbram       1,693
# 12   Central Bohemian Region             Rakovník         896
# 13     South Bohemian Region     České Budějovice       1,639
# ...

# %%
regions_data
# Out:
#    Licence\nplate             Region           Capital Population\n(2022)  \
# 0               A             Prague            Prague          1,275,406
# 1               S   Central Bohemian            Prague          1,386,824
# 2               C     South Bohemian  České Budějovice            637,047
# 3               P              Plzeň             Plzeň            578,707
# 4               K       Karlovy Vary      Karlovy Vary            283,210
# 5               U     Ústí nad Labem    Ústí nad Labem            798,898
# 6               L            Liberec           Liberec            437,570
# 7               H     Hradec Králové    Hradec Králové            542,583
# 8               E          Pardubice         Pardubice            514,518
# 9               J           Vysočina           Jihlava            504,025
# 10              B     South Moravian              Brno          1,184,568
# 11              M            Olomouc           Olomouc            622,930
# ...

# %% [markdown]
# The above data was obtained from Wikipedia

# %%
from sklearn.base import BaseEstimator, TransformerMixin
import re

class PrahaTransform(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        pattern = re.compile('praha-\d{1,2}$')
        X['district'] = X['district'].map(lambda x: 'Praha' if pattern.match(x) else x)    
        return X

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"/pythonScripts")
from URL_helper import URL_helper

# do something about the path. It's obnoxious.

class AddDistrictsAttributes(BaseEstimator, TransformerMixin):
        
    def fit(self, X, y=None):
        return self
    
    def __extractDistrictsData(self, X, regions_data, y=None):
        helper = URL_helper()
        
        return X
        
    def transform(self, X, y=None):
        self.regions_data = pd.read_csv('/Users/eugenganenco/Desktop/srealtyAnalysis/data/Regional Data/Regions_of_the_Czech_Republic_1.csv')
        self.districts_data = pd.read_csv('/Users/eugenganenco/Desktop/srealtyAnalysis/data/Regional Data/Districts_of_the_Czech_Republic_1.csv')
        helper = URL_helper()
        X['Distric_in_czech'] = X['district'].map(helper.getEnglishNameToCzechDict())
        X = pd.merge(X, self.districts_data, left_on='Distric_in_czech', right_on='District')
        self.regions_data = self.regions_data.drop(['Population\n(2022)', 'Area\n(km2)', 'Pop. density\n(/km2)', 'Licence\nplate'], axis=1)
        self.regions_data = self.regions_data.drop(14, axis=0)
        X['Region'] = X['Region'].map(lambda x: x.replace(' Region', ''), na_action='ignore')
        X = pd.merge(self.regions_data, X)
        X = X.drop(['district', 'Distric_in_czech', 'Region', 'Capital', 'District', 'Mun.'], axis=1)
        for feature in ['GDP\n(million CZK, 2022)', 'GDP per\ncapita', 'Area\n(km2)', 'Population\n(2022)']:
            if X[feature].dtypes == 'O':               
                X.loc[:,feature] = X.loc[:,feature].map(lambda x: x.replace(',',''), na_action='ignore')
                X.loc[:,feature] = pd.to_numeric(X.loc[:,feature])
        print('Columns:')
        print(X.columns)
        return X

# %%
# after AddDistrictsAttributes
class CombinedAttributesAdder(BaseEstimator, TransformerMixin):
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        X['Population density'] = X['Area\n(km2)'] / X['Population\n(2022)']
        return X

# %% [markdown]
# ## Data cleaning

# %%
class ExtractAreaValue(BaseEstimator, TransformerMixin):
    def __init__(self, add_gardern_area=False):
        self.add_gardern_area = add_gardern_area

    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        featureList = [feature for feature in X.filter(like='area').columns]
        if not self.add_gardern_area:
            featureList.remove('Garden area')
            X = X.drop('Garden area', axis=1)
        featuresModified = X.loc[:,featureList].applymap(lambda x: re.sub('(m2)', '', x), na_action='ignore')
        for feature in featureList:
            X[feature] = featuresModified[feature]
            X[feature] = pd.to_numeric(X[feature])
        return X

# %%
#class ExtractYearValue()

# %%
class ExtractTheRightVars(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        X = X.loc[:,['district', 'Usable area', 'Land area', 'proximityIndex', 'Built-up area', 'Garden area', 'Floor area']]
        return X

# %%
class DeleteIrrelevantColumns(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        X = X.loc[:, ~df.columns.str.contains('^Unnamed')]
        X = X.drop(['link', 'location', 'total price', 'Update', 'Move-in date', 'Discounted', 'Original price'], inplace=True, axis=1)
        return X

# %%
class CustonImputer(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        for feature in [feature for feature in X.columns if X[feature].dtypes != 'O']:
            median=X[feature].median()
            X[feature].fillna(median, inplace=True)
        return X

# %%
class Debug(BaseEstimator, TransformerMixin):

    def transform(self, X):
        print('////////////////////////////////////')
        print('////////////////////////////////////')
        print(pd.DataFrame(X).head(5))
        print(X.shape)
        print('////////////////////////////////////')
        print('////////////////////////////////////')
        return X

    def fit(self, X, y=None, **fit_params):
        return self

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# %%
# Do something about outliers
num_pipeline = Pipeline([
        ('praha_transform', PrahaTransform()),
        ('feature_selector', ExtractTheRightVars()),
        ('extract_area_vals', ExtractAreaValue()),
        ('add_districs_attributes', AddDistrictsAttributes()),
        ('add_combined_attributes', CombinedAttributesAdder()),
        ('imputer', SimpleImputer(strategy='median')),
        ('std_scaler', MinMaxScaler())
    ])

# %%
features_prepared = num_pipeline.fit_transform(features)
# Out:
# Columns:
# Index(['GDP\n(million CZK, 2022)', 'GDP per\ncapita', 'Usable area',
#        'Land area', 'proximityIndex', 'Built-up area', 'Floor area',
#        'Area\n(km2)', 'Population\n(2022)'],
#       dtype='object')

# %% [markdown]
# ## Select and train the model

# %% [markdown]
# ### Training the models

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(features_prepared, target)
# Out:
# LinearRegression()

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor(random_state=42)
tree_reg.fit(features_prepared, target)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
# from sklearn.ensemble import RandomForestRegressor

# forest_reg = RandomForestRegressor(n_estimators=100, random_state=42)
# forest_reg.fit(features_prepared, target)

# %%
from sklearn.svm import SVR

svm_reg = SVR(kernel="linear")
svm_reg.fit(features_prepared, target)
# Out:
# SVR(kernel='linear')

# %% [markdown]
# ### Evaluating the models

# %%
from sklearn.model_selection import cross_val_score
import numpy as np

scores = cross_val_score(tree_reg, features_prepared, target,
                         scoring="neg_mean_squared_error", cv=10)
tree_rmse_scores = np.sqrt(-scores)
display_scores(tree_rmse_scores)
# Out:
# Scores: [11247803.90537657 13012678.42007519 10800207.60786486 12279113.51816391
#  10392944.20589282  9687226.44963823  9921093.25178497 10554738.88442601
#  10349064.87022639 10390221.68540514]
# Mean: 10863509.27988541
# Standard deviation: 992560.6744116549

# %%
lin_scores = cross_val_score(lin_reg, features_prepared, target,
                             scoring="neg_mean_squared_error", cv=10)
lin_rmse_scores = np.sqrt(-lin_scores)
display_scores(lin_rmse_scores)
# Out:
# Scores: [7194437.2464088  9853822.58038154 7558060.18405422 6396366.04440814
#  7268451.96276882 6235779.33665045 7173059.31774961 7623611.74440996
#  6867941.96589416 6162621.2611871 ]
# Mean: 7233415.164391279
# Standard deviation: 1005319.4111921483

# %%
# forest_scores = cross_val_score(forest_reg, features_prepared, target,
#                                 scoring="neg_mean_squared_error", cv=10)
# forest_rmse_scores = np.sqrt(-forest_scores)
# display_scores(forest_rmse_scores)

# %%
forest_scores = cross_val_score(svm_reg, features_prepared, target,
                                scoring="neg_mean_squared_error", cv=10)
svm_reg_scores = np.sqrt(-forest_scores)
display_scores(svm_reg_scores)
# Out:
# Scores: [ 7358776.49639303 10113572.33970074  7761913.16841495  6558989.63326653
#   7475015.09733163  6477566.19633879  7360138.60712908  7926584.16305197
#   7129769.78805419  6351784.65910674]
# Mean: 7451411.014878765
# Standard deviation: 1023923.5245207936

# %% [markdown]
# ## Evaluate Your System on the Test Set

# %%
from sklearn.metrics import mean_squared_error
final_model = lin_reg

X_test = test_set.drop('price', axis=1)
y_test = test_set['price'].copy()

X_test_prepared = num_pipeline.transform(X_test)
final_predictions = final_model.predict(X_test_prepared)

final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)
# Out:
# Columns:
# Index(['GDP\n(million CZK, 2022)', 'GDP per\ncapita', 'Usable area',
#        'Land area', 'proximityIndex', 'Built-up area', 'Floor area',
#        'Area\n(km2)', 'Population\n(2022)'],
#       dtype='object')

# %%
X_test_prepared
# Out:
# array([[1.        , 1.        , 0.00212094, ..., 0.15501166, 1.        ,
#         0.        ],
#        [1.        , 1.        , 0.00706227, ..., 0.15501166, 1.        ,
#         0.        ],
#        [1.        , 1.        , 0.00640794, ..., 0.15501166, 1.        ,
#         0.        ],
#        ...,
#        [0.28      , 0.10421988, 0.00268502, ..., 0.07342657, 0.16434533,
#         0.04048402],
#        [0.28      , 0.10421988, 0.00336191, ..., 0.07342657, 0.16434533,
#         0.04048402],
#        [0.28      , 0.10421988, 0.00900271, ..., 0.07342657, 0.16434533,
#         0.04048402]])

# %%
final_model.coef_
# Out:
# array([ 1068949.06696671,  -127346.20158954,  3485702.62600474,
#         2106623.23319437,   151157.07668842, -6132318.36565812,
#         1110583.91429885,  -122050.39851929,    39666.35014074,
#          391369.0346417 ])

# %% [markdown]
# 'Usable area', 'Land area', 'proximityIndex', 'Built-up area', 'Garden area', 'Floor area'

# %%
final_model.intercept_
# Out:
# 7068029.6599686025

# %%
final_rmse
# Out:
# 7074793.113292905

# %%
print(final_predictions[:10])
y_test[:10]
# Out:
# [8051803.75235764 8025809.93846412 7955085.30307225 8055338.80268233
#  8028962.01770032 8050579.37389881 8026258.80616641 8024444.82438523
#  8038140.34146448 7959398.39274505]
# 5684     1200000
# 4880     7790000
# 14202    4941000
# 13703    2060000
# 8175     2863000
# 7200     1800000
# 4131     8770000
# 13327    6350000
# 8377     2200000
# 132       950000
# Name: price, dtype: int64
