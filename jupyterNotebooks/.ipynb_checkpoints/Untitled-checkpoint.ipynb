# %%
import pandas as pd

pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

DATA_PATH = '/Users/eugenganenco/Desktop/srealtyAnalysis/data/DataFile 16_11_2022_22_43/housesDf_17_11_2022_00_06_15.csv translatedWithCoordAndPrice.csv'
df = pd.read_csv(DATA_PATH)
df = df.loc[df['price'] != 0]

# %%
## First lets handle categorical features which are missing
## Move to data analysis file

def percentageMissing(feature):
    missingValues = df[feature].apply(lambda x: 1 if pd.isna(x) else 0).sum()
    return round((missingValues/len(df.axes[0])) * 100, 3)

def getMissingFeaturesDict(featuresWithNan):
    missingFeaturesDict = {}
    for feature in featuresWithNan:
        percentage = percentageMissing(feature)
        missingFeaturesDict[feature] = percentage
    return sorted(missingFeaturesDict.items(), key=lambda x: x[1], reverse=True)

featuresWithNan=[feature for feature in df.columns if df[feature].isnull().sum() > 0]
missingFeaturesDict = getMissingFeaturesDict(featuresWithNan)

for index, feature in enumerate(missingFeaturesDict):
    print('Variable "{}"" has {}% of its values missing'.format(missingFeaturesDict[index][0], missingFeaturesDict[index][1]))
# Out:
# Variable "Cena"" has 100.0% of its values missing
# Variable "Starting price"" has 100.0% of its values missing
# Variable "Expert opinion"" has 100.0% of its values missing
# Variable "The date of the 1st inspection"" has 100.0% of its values missing
# Variable "The date of the 2nd inspection"" has 100.0% of its values missing
# Variable "Minimum purchase price"" has 100.0% of its values missing
# Variable "Minimum bid"" has 99.993% of its values missing
# Variable "Auction principal"" has 99.993% of its values missing
# Variable "Type of auction"" has 99.993% of its values missing
# Variable "Place of auction"" has 99.993% of its values missing
# Variable "The date of the auction"" has 99.993% of its values missing
# Variable "Auction decree"" has 99.993% of its values missing
# Variable "Expert opinion.1"" has 99.993% of its values missing
# Variable "Number of owners"" has 99.986% of its values missing
# Variable "Share size"" has 99.971% of its values missing
# Variable "Inspection date to"" has 99.899% of its values missing
# Variable "Inspection date"" has 99.286% of its values missing
# Variable "Date of completion of construction"" has 98.997% of its values missing
# Variable "Pool area"" has 98.976% of its values missing
# Variable "Number of flats"" has 98.947% of its values missing
# Variable "Ceiling height"" has 98.875% of its values missing
# Variable "Soil construction"" has 98.586% of its values missing
# Variable "Sale start date"" has 98.478% of its values missing
# Variable "Condition"" has 98.269% of its values missing
# Variable "Housing costs"" has 96.689% of its values missing
# Variable "Discounted"" has 95.931% of its values missing
# Variable "Original price"" has 95.931% of its values missing
# Variable "Certificate of energy performance of the building"" has 94.856% of its values missing
# Variable "Swimming pool"" has 93.147% of its values missing
# Variable "ID"" has 91.61% of its values missing
# Variable "Indicator of energy efficiency of the building"" has 91.552% of its values missing
# Variable "Year of approval"" has 91.185% of its values missing
# Variable "Year of reconstruction"" has 89.9% of its values missing
# Variable "Barrier-free"" has 79.685% of its values missing
# Variable "Telecommunication"" has 75.141% of its values missing
# Variable "Move-in date"" has 71.296% of its values missing
# Variable "Garden area"" has 70.791% of its values missing
# Variable "Gas"" has 70.43% of its values missing
# Variable "Floor area"" has 70.358% of its values missing
# Variable "Lift"" has 67.617% of its values missing
# Variable "Garage"" has 65.842% of its values missing
# Variable "Store"" has 64.724% of its values missing
# Variable "Communication"" has 59.349% of its values missing
# Variable "Parking"" has 55.915% of its values missing
# Variable "Note on price"" has 46.422% of its values missing
# Variable "Equipment"" has 40.564% of its values missing
# Variable "Transport"" has 38.818% of its values missing
# Variable "Heating"" has 34.526% of its values missing
# Variable "Built-up area"" has 34.324% of its values missing
# Variable "Electricity"" has 31.381% of its values missing
# Variable "Water"" has 28.676% of its values missing
# Variable "Object location"" has 28.474% of its values missing
# Variable "Garbage"" has 25.35% of its values missing
# Variable "The floor"" has 22.861% of its values missing
# Variable "Energy efficiency of the building"" has 12.711% of its values missing
# Variable "Location of the house"" has 10.186% of its values missing
# Variable "Job ID"" has 8.39% of its values missing
# Variable "Land area"" has 0.079% of its values missing

# %% [markdown]
# ## Split data

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(df, test_size=0.2, random_state=17)

# %%
features = train_set.drop("price", axis=1)
target = train_set['price'].copy()

# %% [markdown]
# ## Data cleaning

# %%
from sklearn.base import BaseEstimator, TransformerMixin
import re

class ExtractAreaValue(BaseEstimator, TransformerMixin):
    def __init__(self, add_gardern_area=False):
        self.add_gardern_area = add_gardern_area

    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        featureList = [feature for feature in X.filter(like='area').columns]
        if not self.add_gardern_area:
            featureList.remove('Garden area')
            X = X.drop('Garden area', axis=1)
        featuresModified = X.loc[:,featureList].applymap(lambda x: re.sub('(m2)', '', x), na_action='ignore')
        for feature in featureList:
            X[feature] = featuresModified[feature]
            X[feature] = pd.to_numeric(X[feature])
        return X

# %%
#class ExtractYearValue()

# %%
class ExtractTheRightVars(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        X = X.loc[:,['Usable area', 'Land area', 'proximityIndex', 'Built-up area', 'Garden area', 'Floor area']]
        print(f'Extract vars{X.shape}')
        return X

# %%
class DeleteIrrelevantColumns(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        X = X.loc[:, ~df.columns.str.contains('^Unnamed')]
        X = X.drop(['link', 'location', 'total price', 'Update', 'Move-in date', 'Discounted', 'Original price'], inplace=True, axis=1)
        return X

# %%
class CustonImputer(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        for feature in [feature for feature in X.columns if X[feature].dtypes != 'O']:
            median=X[feature].median()
            X[feature].fillna(median, inplace=True)
        return X

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# %%
# Do something about outliers
num_pipeline = Pipeline([
        ('feature_selector', ExtractTheRightVars()),
        ('extract_area_vals', ExtractAreaValue()),
        ('imputer', SimpleImputer(strategy='median')),
        ('std_scaler', MinMaxScaler())
    ])

# %%
features_prepared = num_pipeline.fit_transform(features)
# Out:
# Extract vars(11089, 6)

# %% [markdown]
# ## Select and train the model

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(features_prepared, target)
# Out:
# LinearRegression()

# %% [markdown]
# ## Evaluate Your System on the Test Set

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
final_model = lin_reg

X_test = test_set.drop('price', axis=1)
y_test = test_set['price'].copy()

X_test_prepared = num_pipeline.transform(X_test)
final_predictions = final_model.predict(X_test_prepared)

final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)
# Out:
# Extract vars(2773, 6)

# %%
X_test.head(5)
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
#
# 14202        400V             Dálnice, Silnice, Autobus
# 13703        230V           Vlak, Silnice, MHD, Autobus
# 8175         230V                               Silnice
#
#                                      Energy efficiency of the building  \
# 5684   Třída G - Mimořádně nehospodárná č. 264/2020 Sb. podle vyhlášky
# 4880                                                               NaN
# 14202  Třída G - Mimořádně nehospodárná č. 264/2020 Sb. podle vyhlášky
# 13703  Třída G - Mimořádně nehospodárná č. 148/2007 Sb. podle vyhlášky
# 8175                                                               NaN
#
#       Equipment  Lift        companyName  proximityIndex  Index Built-up area  \
# 5684          1   NaN  RE/MAX G8 Reality     1478.500000   5862         44 m2
# 4880          1   NaN            Flatigo     1965.764706   5022           NaN
# 14202         0   NaN     Reality Populo     1812.076923  14680        133 m2
# 13703         0   NaN        ORCA ESTATE      470.545455  14165        150 m2
# 8175          1   NaN  Areality Vysočina     3686.785714   8458         66 m2
#
#        Store  Garage       Gas  \
# 5684     NaN     NaN       NaN
# 4880       1     NaN  Plynovod
# 14202    NaN     NaN       NaN
# 13703  10 m2     NaN  Plynovod
# 8175     NaN     NaN       NaN
#
#                                                               Telecommunication  \
# 5684                                                                        NaN
# 4880   Telefon, Internet, Satelit, Kabelová televize, Kabelové rozvody, Ostatní
# 14202                                                                       NaN
# 13703                                                                       NaN
# 8175                                                                        NaN
#
#       Discounted Original price Garden area  Year of approval  Swimming pool  \
# 5684         NaN            NaN         NaN               NaN            NaN
# 4880         NaN            NaN      101 m2               NaN            NaN
# 14202        NaN            NaN         NaN               NaN            NaN
# 13703        NaN            NaN         NaN               NaN            NaN
# 8175         NaN            NaN         NaN               NaN            NaN
#
#       Cena Floor area Communication  \
# 5684   NaN        NaN           NaN
# 4880   NaN        NaN     Asfaltová
# 14202  NaN        NaN           NaN
# 13703  NaN        NaN     Asfaltová
# 8175   NaN        NaN           NaN
#
#       Indicator of energy efficiency of the building  \
# 5684                                             NaN
# 4880                                             NaN
# 14202                                            NaN
# 13703                                            NaN
# 8175                                             NaN
#
#       Certificate of energy performance of the building  Barrier-free  \
# 5684                                                NaN           NaN
# 4880                                                NaN           NaN
# 14202                                               NaN           NaN
# 13703                                               NaN           NaN
# 8175                                                NaN           NaN
#
#       Ceiling height            ID Housing costs Number of flats  \
# 5684             NaN           NaN           NaN             NaN
# 4880             NaN  1.011837e+09           NaN             NaN
# 14202            NaN           NaN           NaN             NaN
# 13703            NaN           NaN           NaN             NaN
# 8175             NaN           NaN           NaN             NaN
#
#       Starting price Expert opinion Minimum bid Auction principal  \
# 5684             NaN            NaN         NaN               NaN
# 4880             NaN            NaN         NaN               NaN
# 14202            NaN            NaN         NaN               NaN
# 13703            NaN            NaN         NaN               NaN
# 8175             NaN            NaN         NaN               NaN
#
#       Type of auction Place of auction The date of the auction  \
# 5684              NaN              NaN                     NaN
# 4880              NaN              NaN                     NaN
# 14202             NaN              NaN                     NaN
# 13703             NaN              NaN                     NaN
# 8175              NaN              NaN                     NaN
#
#       The date of the 1st inspection The date of the 2nd inspection  \
# 5684                             NaN                            NaN
# 4880                             NaN                            NaN
# 14202                            NaN                            NaN
# 13703                            NaN                            NaN
# 8175                             NaN                            NaN
#
#       Auction decree Expert opinion.1 Pool area    Condition  \
# 5684             NaN              NaN       NaN  Rezervováno
# 4880             NaN              NaN       NaN          NaN
# 14202            NaN              NaN       NaN          NaN
# 13703            NaN              NaN       NaN          NaN
# 8175             NaN              NaN       NaN          NaN
#
#       Date of completion of construction  Soil construction Sale start date  \
# 5684                                 NaN                NaN             NaN
# 4880                                 NaN                NaN             NaN
# 14202                                NaN                NaN             NaN
# 13703                                NaN                NaN             NaN
# 8175                                 NaN                NaN             NaN
#
#         Inspection date Inspection date to Minimum purchase price Share size  \
# 5684                NaN                NaN                    NaN        NaN
# 4880   14.11.2022 13:00                NaN                    NaN        NaN
# 14202               NaN                NaN                    NaN        NaN
# 13703               NaN                NaN                    NaN        NaN
# 8175                NaN                NaN                    NaN        NaN
#
#        Number of owners locationLat locationLong
# 5684                NaN  49.8629922   14.5033881
# 4880                NaN  50.1091982   14.8549955
# 14202               NaN  49.2543014   17.5449443
# 13703               NaN  49.9819413   16.8827113
# 8175                NaN  49.3433062   14.4967343

# %%
X_test_prepared
# Out:
# array([[9.70216606e-04, 4.98965517e-05, 3.25676734e-01, 3.94278379e-03,
#         8.74513327e-03],
#        [3.04602888e-03, 2.58765838e-04, 4.33009015e-01, 1.20117367e-02,
#         8.74513327e-03],
#        [2.97833935e-03, 1.11977145e-03, 3.99155424e-01, 1.21034293e-02,
#         8.74513327e-03],
#        ...,
#        [3.63267148e-03, 8.88854851e-04, 1.94074600e-01, 8.34403081e-03,
#         9.64360587e-03],
#        [2.91064982e-03, 4.53710505e-04, 1.16703845e-01, 4.85971025e-03,
#         6.94818808e-03],
#        [9.92779783e-04, 3.44634322e-04, 3.67839391e-01, 4.49293967e-03,
#         8.74513327e-03]])

# %%
final_model.coef_
# Out:
# array([49681704.06687217, 75437097.69974391, -5564401.40840035,
#        18313905.15259978, 43221588.33039649])

# %% [markdown]
# 'Usable area', 'Land area', 'proximityIndex', 'Built-up area', 'Garden area', 'Floor area'

# %%
final_model.intercept_
# Out:
# 8234182.122601223

# %%
final_rmse
# Out:
# 6851613.145991791

# %%
print(final_predictions[:10])
y_test[:10]
# Out:
# [6924138.42889711 6593558.95257486 6845202.00903257 8574719.11014145
#  4307236.29851112 7887653.64777648 5776067.52824357 8119227.56034702
#  5077734.00340596 7019960.26436165]
# 5684     1200000
# 4880     7790000
# 14202    4941000
# 13703    2060000
# 8175     2863000
# 7200     1800000
# 4131     8770000
# 13327    6350000
# 8377     2200000
# 132       950000
# Name: price, dtype: int64
